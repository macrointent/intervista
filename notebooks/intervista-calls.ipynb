# %%
import requests
from requests.auth import HTTPBasicAuth
import json
import os
import sys
sys.path.append(os.path.abspath(".."))
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
base = os.getenv("INTERVISTA_URL")
path = os.getenv("INTERVISTA_PATH")
user= os.getenv("INTERVISTA_USER")
pwd= os.getenv("INTERVISTA_PWD")

# %%
pv_ids = [
    "64",
    "3415",
    "3424",
    "3436",
    "3448",
    "3571",
    "3610",
]

# %% [markdown]
# # Get product configurations from intervista backend

# %%
data = []
for pv_id in pv_ids:
    url = f"{base}{pv_id}{path}"
    session = requests.Session()
    response = session.get(url, auth=HTTPBasicAuth(user, pwd))
    data.append(response.json()['result'][0])

print(json.dumps(data, indent=2, ensure_ascii=False))
# Out:
# [
#   {
#     "product": {
#       "productId": 46,
#       "productVariantId": 64,
#       "name": "FirmenSchutzbrief (Standardtarif)",
#       "description": "FirmenSchutzbrief by ELEMENT",
#       "versionInfo": "FirmenSchutzbrief by ELEMENT",
#       "displayName": "FirmenSchutzbrief by ELEMENT",
#       "tooltip": null,
#       "state": "Offen für den Bestand",
#       "typeId": -101001,
#       "availableFrom": 1614902400000,
#       "availableTo": null,
#       "personSpecific": false,
#       "providerId": 10,
#       "providerName": "ELEMENT",
#       "providerShortName": "EL",
#       "tag": [
#         "Versicherung",
#         "Geschäftskundentarif",
#         "FirmenSchutz",
#         "Einzelversicherung",
#         "Multigerätetarif"
#       ],
#       "tagrenderdata": null,
#       "rule": [
#         "de.schutzgarant.core.plugins.FirmenSchutzPlausiPlugin",
#         "de.schutzgarant.core.plugins.GesamtVersicherungssummenBerechner",
#         "at.intervista.collactive.sellactive.plugin.plausi.RelatedDocumentCheckerPlugin",
#         "at.intervista.collactive.sellactive.plugin.pdf.xslt.XsltFoPrintPlugin",
#         "de.schutzgarant.core.plugins.GeraetePlausiPlugin",
#         "de.schutzgarant.core.plugins.claim.ClaimAfterDateOfExpiry",
#         "de.schutzgarant.core.plugins.claim.SchadenVorfristigPlugin",
#         "at.intervista.collactive.sellactive.plugin.plausi.PersonInformationChecker"
#       ],
#       "externalcode": []
#     },
#     "attributecategorie": [
#       {
#         "name": "Allgemeine Kategorie",
#         "displayName": "Allgemeine Kategorie",
#         "rank": 30,
#         "expandable": false,
#         "collapse": null,
#         "header": "",
#         "footer": "",
#         "displayAttributeCategoryDtoMap": {
#           "Diebstahl": {
#             "collapse": null,
#             "header": "",
#             "footer": ""
#           },
#           "SelfActive Erfassung": {
#             "collapse": null,
#             "header": "",
#             "footer": ""
#           },
#           "Geräteimport": {
#             "collapse": null,
#             "header": "",
#             "footer": ""
#           },
#           "Provisionierung": {
#             "collapse": null,
#             "header": "",
#             "footer": ""
#           },
#           "Vertrag": {
#             "collapse": null,
#             "header": "",
#             "footer": ""
#           },
#           "Vertragsvorlage": {
#             "collapse": null,
#             "header": "",
#             "footer": ""
#           },
#           "Beitragsberechnung": {
#             "collapse": null,
#             "header": "",
#             "footer": ""
#           },
#           "TouchActive Extra": {
#             "collapse": null,
#             "header": "",
#             "footer": ""
#           },
#           "Schaden": {
#             "collapse": null,
#             "header": "",
#             "footer": ""
#           },
#           "Vermittlermerkmale": {
#             "collapse": null,
#             "header": "",
#             "footer": ""
#           },
#           "Eingabedaten": {
#             "collapse": null,
#             "header": "",
#             "footer": ""
#           },
#           "Dokumentgenerierung": {
#             "collapse": null,
#             "header": "",
#             "footer": ""
#           },
#           "TouchActive Erfassung": {
#             "collapse": null,
#             "header": "",
#             "footer": ""
#           },
#           "Visuals": {
#             "collapse": null,
#             "header": "",
#             "footer": ""
#           }
#         },
#         "attribute": [
#           {
#             "attributeId": 22,
#             "productVariantAttributeId": 328,
#             "name": "selectionMarker",
#             "displayName": "ausgewählt",
#             "displayDescription": "",
#             "catName": "Allgemeine Kategorie",
#             "catDisplayName": "Allgemeine Kategorie",
#             "catRank": 30,
#             "attributeCategoryId": -1,
#             "placeholder": null,
#             "description": "",
#             "type": "Auswahl",
#             "typeId": -102010,
#             "value": "true",
#             "inputField": true,
#             "hide": true,
#             "advanced": false,
#             "dynamicLoaderId": null,
#             "productVariantId": 64,
#             "productName": "FirmenSchutzbrief (Standardtarif)",
#             "personAttributeTypeId": null,
#             "documentAttributeTypeId": null,
#             "businessObjectAttributeTypeId": null,
#             "required": false,
#             "rank": 0,
#             "listId": null,
#             "properties": {},
#             "autocomplete": null,
#             "autofocus": null,
#             "readonly": null,
#             "size": null,
#             "min": null,
#             "max": null,
#             "minDate": null,
#             "maxDate": null,
#             "minLength": null,
#             "maxLength": null,
#             "placeholderDpva": "",
#             "stepwise": null,
#             "aspectDisplayNames": {},
#             "listelement": null,
#             "validationrule": [],
#             "aspect": [
#               "SelfActive Erfassung",
#               "Beitragsberechnung",
#               "TouchActive Erfassung",
#               "CollActive Erfassung"
#             ],
#             "evaluation": [],
#             "externalcode": []
#           },
#           {
#             "attributeId": 181,
#             "productVariantAttributeId": 3304,
#             "name": "DocumentChecker: Id Dokumentenattribut",
#             "displayName": "DocumentChecker: Id Dokumentenattribut",
#             "displayDescription": "",
#             "catName": "Allgemeine Kategorie",
#             "catDisplayName": "Allgemeine Kategorie",
#             "catRank": 30,
#             "attributeCategoryId": -1,
#             "placeholder": null,
#             "description": "",
#             "type": "Text",
#             "typeId": -102009,
#             "value": "-300",
#             "inputField": false,
#             "hide": true,
#             "advanced": false,
#             "dynamicLoaderId": null,
#             "productVariantId": 64,
#             "productName": "FirmenSchutzbrief (Standardtarif)",
#             "personAttributeTypeId": null,
#             "documentAttributeTypeId": null,
#             "businessObjectAttributeTypeId": null,
#             "required": false,
#             "rank": 0,
#             "listId": null,
#             "properties": {},
#             "autocomplete": null,
#             "autofocus": null,
#             "readonly": null,
#             "size": null,
#             "min": null,
#             "max": null,
#             "minDate": null,
#             "maxDate": null,
#             "minLength": null,
#             "maxLength": null,
#             "placeholderDpva": "",
#             "stepwise": null,
#             "aspectDisplayNames": {},
#             "listelement": null,
#             "validationrule": null,
#             "aspect": [
#               "SelfActive Erfassung"
#             ],
#             "evaluation": [],
#             "externalcode": []
#           },
#           {
#             "attributeId": 184,
#             "productVariantAttributeId": 3307,
#             "name": "DocumentChecker: Name Attribut an Vertrag",
#             "displayName": "DocumentChecker: Name Attribut an Vertrag",
#             "displayDescription": "",
#             "catName": "Allgemeine Kategorie",
#             "catDisplayName": "Allgemeine Kategorie",
#             "catRank": 30,
#             "attributeCategoryId": -1,
#             "placeholder": null,
#             "description": "",
#             "type": "Text",
#             "typeId": -102009,
#             "value": "Versicherungsschein-Nr.",
#             "inputField": false,
#             "hide": true,
#             "advanced": false,
#             "dynamicLoaderId": null,
#             "productVariantId": 64,
#             "productName": "FirmenSchutzbrief (Standardtarif)",
#             "personAttributeTypeId": null,
#             "documentAttributeTypeId": null,
#             "businessObjectAttributeTypeId": null,
#             "required": false,
#             "rank": 0,
#             "listId": null,
#             "properties": {},
#             "autocomplete": null,
#             "autofocus": null,
#             "readonly": null,
#             "size": null,
#             "min": null,
#             "max": null,
#             "minDate": null,
#             "maxDate": null,
#             "minLength": null,
#             "maxLength": null,
#             "placeholderDpva": "",
#             "stepwise": null,
#             "aspectDisplayNames": {},
#             "listelement": null,
#             "validationrule": null,
#             "aspect": [
#               "SelfActive Erfassung"
#             ],
#             "evaluation": [],
#             "externalcode": []
#           }
#         ]
#       },
#       {
#         "name": "Vertragsdetails",
#         "displayName": "Vertragsdetails",
#         "rank": 100,
#         "expandable": false,
#         "collapse": null,
#         "header": "",
#         "footer": "",
#         "displayAttributeCategoryDtoMap": {
#           "Beitragsberechnung": {
#             "collapse": null,
#             "header": "",
#             "footer": ""
#           },
#           "SelfActive Erfassung": {
#             "collapse": null,
#             "header": "",
#             "footer": ""
#           },
#           "TouchActive Extra": {
#             "collapse": null,
#             "header": "",
#             "footer": ""
#           },
#           "Vertriebskennzeichen": {
#             "collapse": null,
#             "header": "",
#             "footer": ""
#           },
#           "Provisionierung": {
#             "collapse": null,
#             "header": "",
#             "footer": ""
#           },
#           "CollActive Erfassung": {
#             "collapse": null,
#             "header": "",
#             "footer": ""
#           },
#           "Eingabedaten": {
#             "collapse": null,
#             "header": "",
#             "footer": ""
#           },
#           "Vertragsvorlage": {
#             "collapse": null,
#             "header": "",
#             "footer": ""
#           },
#           "Dokumentgenerierung": {
#             "collapse": null,
#             "header": "",
#             "footer": ""
#           },
#           "TouchActive Erfassung": {
#             "collapse": null,
#             "header": "",
#             "footer": ""
#           }
#         },
#         "attribute": [
#           {
#             "attributeId": 7,
#             "productVariantAttributeId": 316,
#             "name": "Gerätekategorie",
#             "displayName": "Gerätekategorie",
#             "displayDescription": "Bitte wählen Sie hier Ihre jeweilige Gerätekategorie aus. \"Sonstige Geräte\" sind z.B. Drucker, PC´s, Kameras, Beamer etc.",
#             "catName": "Vertragsdetails",
#             "catDisplayName": "Vertragsdetails",
#             "catRank": 100,
#             "attributeCategoryId": 2,
#             "placeholder": null,
#             "description": "Bitte wählen Sie hier Ihre jeweilige Gerätekategorie aus. \"Sonstige Geräte\" sind z.B. Drucker, PC´s, Kameras, Beamer etc.",
#             "type": "Liste",
#             "typeId": -102014,
#             "value": "Smartphones & Handys",
#             "inputField": true,
#             "hide": false,
#             "advanced": false,
#             "dynamicLoaderId": null,
#             "productVariantId": 64,
#             "productName": "FirmenSchutzbrief (Standardtarif)",
#             "personAttributeTypeId": null,
#             "documentAttributeTypeId": null,
#             "businessObjectAttributeTypeId": null,
#             "required": true,
#             "rank": 0,
#             "listId": 1,
#             "properties": {},
#             "autocomplete": null,
#             "autofocus": null,
#             "readonly": null,
#             "size": null,
#             "min": null,
#             "max": null,
#             "minDate": null,
#             "maxDate": null,
#             "minLength": null,
#             "maxLength": null,
#             "placeholderDpva": "",
#             "stepwise": null,
#             "aspectDisplayNames": {},
#             "listelement": [
#               {
#                 "listelementId": 300010,
#                 "name": "Smartphones & Handys",
#                 "description": null,
#                 "availableFrom": null,
#                 "availableTo": null,
#                 "rank": 100,
#                 "valid": true,
#                 "externalcode": [
#                   {
#                     "externalCodeId": 103,
#                     "value": "Smartphones und Handys",
#                     "aspect": "SelfActive Erfassung",
#                     "aspectId": 14419
#                   }
#                 ]
#               },
#               {
#                 "listelementId": 300007,
#                 "name": "Notebooks & Tablets",
#                 "description": null,
#                 "availableFrom": null,
#                 "availableTo": null,
#                 "rank": 200,
#                 "valid": true,
#                 "externalcode": [
#                   {
#                     "externalCodeId": 106,
#                     "value": "Tablets und Notebooks",
#                     "aspect": "SelfActive Erfassung",
#                     "aspectId": 14419
#                   }
#                 ]
#               },
#               {
#                 "listelementId": 300004,
#                 "name": "Sonstige Geräte",
#                 "description": null,
#                 "availableFrom": null,
#                 "availableTo": null,
#                 "rank": 300,
#                 "valid": true,
#                 "externalcode": [
#                   {
#                     "externalCodeId": 109,
#                     "value": "Sonstige IT-Geräte der allgemeinen Bürotechnik",
#                     "aspect": "SelfActive Erfassung",
#                     "aspectId": 14419
#                   }
#                 ]
#               }
#             ],
#             "validationrule": [],
#             "aspect": [
#               "SelfActive Erfassung",
#               "Beitragsberechnung",
#               "Vertragsvorlage",
#               "TouchActive Erfassung",
#               "Dokumentgenerierung",
#               "CollActive Erfassung"
#             ],
#             "evaluation": [],
#             "externalcode": []
#           },
#           {
#             "attributeId": 4,
#             "productVariantAttributeId": 313,
#             "name": "Vertragslaufzeit",
#             "displayName": "Laufzeit in Monaten",
#             "displayDescription": "Bitte wählen Sie hier die Vertragslaufzeit aus, wie viele Monate die Geräte von jetzt ab versichert werden sollen. <b>Die Mindestlaufzeit beträgt 12 Monate.</b>",
#             "catName": "Vertragsdetails",
#             "catDisplayName": "Vertragsdetails",
#             "catRank": 100,
#             "attributeCategoryId": 2,
#             "placeholder": null,
#             "description": "Bitte wählen Sie hier die Vertragslaufzeit aus, wie viele Monate die Geräte von jetzt ab versichert werden sollen. <b>Die Mindestlaufzeit beträgt 12 Monate.</b>",
#             "type": "Zahl",
#             "typeId": -102011,
#             "value": "24",
#             "inputField": true,
#             "hide": false,
#             "advanced": false,
#             "dynamicLoaderId": null,
#             "productVariantId": 64,
#             "productName": "FirmenSchutzbrief (Standardtarif)",
#             "personAttributeTypeId": null,
#             "documentAttributeTypeId": null,
#             "businessObjectAttributeTypeId": null,
#             "required": true,
#             "rank": 100,
#             "listId": null,
#             "properties": {
#               "min": "12",
#               "max": "60"
#             },
#             "autocomplete": null,
#             "autofocus": null,
#             "readonly": null,
#             "size": null,
#             "min": 12.0,
#             "max": 60.0,
#             "minDate": null,
#             "maxDate": null,
#             "minLength": null,
#             "maxLength": null,
#             "placeholderDpva": "",
#             "stepwise": null,
#             "aspectDisplayNames": {},
#             "listelement": null,
#             "validationrule": [
#               {
#                 "regularExpression": "^([1][2-9]|[2-5][0-9]|60)$",
#                 "min": 12.0,
#                 "max": 60.0,
#                 "expectedValidationResult": true,
#                 "validationFailureMessage": "Vertragslaufzeit muss zwischen 12 und 60 Monaten liegen",
#                 "validationFailureI18N": null,
#                 "minDate": null,
#                 "maxDate": null,
#                 "stepwise": null,
#                 "minLength": null,
#                 "maxLength": null
#               }
#             ],
#             "aspect": [
#               "SelfActive Erfassung",
#               "Beitragsberechnung",
#               "Vertragsvorlage",
#               "TouchActive Erfassung",
#               "CollActive Erfassung"
#             ],
#             "evaluation": [],
#             "externalcode": []
#           },
#           {
#             "attributeId": 319,
#             "productVariantAttributeId": 3691,
#             "name": "Aktionscode",
#             "displayName": "Aktionscode",
#             "displayDescription": "",
#             "catName": "Vertragsdetails",
#             "catDisplayName": "Vertragsdetails",
#             "catRank": 100,
#             "attributeCategoryId": 2,
#             "placeholder": null,
#             "description": "",
#             "type": "Text",
#             "typeId": -102009,
#             "value": "",
#             "inputField": true,
#             "hide": true,
#             "advanced": true,
#             "dynamicLoaderId": null,
#             "productVariantId": 64,
#             "productName": "FirmenSchutzbrief (Standardtarif)",
#             "personAttributeTypeId": null,
#             "documentAttributeTypeId": null,
#             "businessObjectAttributeTypeId": null,
#             "required": false,
#             "rank": 200,
#             "listId": null,
#             "properties": {},
#             "autocomplete": null,
#             "autofocus": null,
#             "readonly": null,
#             "size": null,
#             "min": null,
#             "max": null,
#             "minDate": null,
#             "maxDate": null,
#             "minLength": null,
#             "maxLength": null,
#             "placeholderDpva": "",
#             "stepwise": null,
#             "aspectDisplayNames": {},
#             "listelement": null,
#             "validationrule": [],
#             "aspect": [
#               "Vertragsvorlage",
#               "SelfActive Erfassung"
#             ],
#             "evaluation": [],
#             "externalcode": []
#           },
#           {
#             "attributeId": 373,
#             "productVariantAttributeId": 6184,
#             "name": "Mindestvertragslaufzeit",
#             "displayName": "Mindestvertragslaufzeit",
#             "displayDescription": "",
#             "catName": "Vertragsdetails",
#             "catDisplayName": "Vertragsdetails",
#             "catRank": 100,
#             "attributeCategoryId": 2,
#             "placeholder": null,
#             "description": "",
#             "type": "Zahl",
#             "typeId": -102011,
#             "value": "12",
#             "inputField": false,
#             "hide": true,
#             "advanced": false,
#             "dynamicLoaderId": null,
#             "productVariantId": 64,
#             "productName": "FirmenSchutzbrief (Standardtarif)",
#             "personAttributeTypeId": null,
#             "documentAttributeTypeId": null,
#             "businessObjectAttributeTypeId": null,
#             "required": false,
#             "rank": 1000,
#             "listId": null,
#             "properties": {},
#             "autocomplete": null,
#             "autofocus": null,
#             "readonly": null,
#             "size": null,
#             "min": null,
#             "max": null,
#             "minDate": null,
#             "maxDate": null,
#             "minLength": null,
#             "maxLength": null,
#             "placeholderDpva": "",
#             "stepwise": null,
#             "aspectDisplayNames": {},
#             "listelement": null,
#             "validationrule": null,
#             "aspect": [
#               "SelfActive Erfassung"
#             ],
#             "evaluation": [],
#             "externalcode": []
#           },
#           {
#             "attributeId": 427,
#             "productVariantAttributeId": 6187,
#             "name": "max. Laufzeit Monate",
#             "displayName": "max. Laufzeit Monate",
#             "displayDescription": "",
#             "catName": "Vertragsdetails",
#             "catDisplayName": "Vertragsdetails",
#             "catRank": 100,
#             "attributeCategoryId": 2,
#             "placeholder": null,
#             "description": "",
#             "type": "Zahl",
#             "typeId": -102011,
#             "value": "60",
#             "inputField": false,
#             "hide": true,
#             "advanced": false,
#             "dynamicLoaderId": null,
#             "productVariantId": 64,
#             "productName": "FirmenSchutzbrief (Standardtarif)",
#             "personAttributeTypeId": null,
#             "documentAttributeTypeId": null,
#             "businessObjectAttributeTypeId": null,
#             "required": false,
#             "rank": 1005,
#             "listId": null,
#             "properties": {},
#             "autocomplete": null,
#             "autofocus": null,
#             "readonly": null,
#             "size": null,
#             "min": null,
#             "max": null,
#             "minDate": null,
#             "maxDate": null,
#             "minLength": null,
#             "maxLength": null,
#             "placeholderDpva": "",
#             "stepwise": null,
#             "aspectDisplayNames": {},
#             "listelement": null,
#             "validationrule": null,
#             "aspect": [
#               "SelfActive Erfassung"
#             ],
#             "evaluation": [],
#             "externalcode": []
#           }
#         ]
#       },
#       {
#         "name": "Zahlungsinformationen",
#         "displayName": "Zahlungsinformationen",
#         "rank": 200,
#         "expandable": false,
#         "collapse": null,
#         "header": "",
#         "footer": "",
#         "displayAttributeCategoryDtoMap": {
#           "Beitragsberechnung": {
#             "collapse": null,
#             "header": "",
#             "footer": ""
#           },
#           "SelfActive Erfassung": {
#             "collapse": null,
#             "header": "",
#             "footer": ""
#           },
#           "Konfiguration": {
#             "collapse": null,
#             "header": "",
#             "footer": ""
#           },
#           "TouchActive Erfassung": {
#             "collapse": null,
#             "header": "",
#             "footer": ""
#           }
#         },
#         "attribute": [
#           {
#             "attributeId": 376,
#             "productVariantAttributeId": 3847,
#             "name": "Zahlungsart",
#             "displayName": "Zahlungsart",
#             "displayDescription": "",
#             "catName": "Zahlungsinformationen",
#             "catDisplayName": "Zahlungsinformationen",
#             "catRank": 200,
#             "attributeCategoryId": 11,
#             "placeholder": null,
#             "description": "",
#             "type": "Liste",
#             "typeId": -102014,
#             "value": "Überweisung",
#             "inputField": true,
#             "hide": true,
#             "advanced": false,
#             "dynamicLoaderId": null,
#             "productVariantId": 64,
#             "productName": "FirmenSchutzbrief (Standardtarif)",
#             "personAttributeTypeId": null,
#             "documentAttributeTypeId": null,
#             "businessObjectAttributeTypeId": null,
#             "required": false,
#             "rank": 100,
#             "listId": -59,
#             "properties": {},
#             "autocomplete": null,
#             "autofocus": null,
#             "readonly": null,
#             "size": null,
#             "min": null,
#             "max": null,
#             "minDate": null,
#             "maxDate": null,
#             "minLength": null,
#             "maxLength": null,
#             "placeholderDpva": "",
#             "stepwise": null,
#             "aspectDisplayNames": {},
#             "listelement": [
#               {
#                 "listelementId": -5901,
#                 "name": "Überweisung",
#                 "description": null,
#                 "availableFrom": null,
#                 "availableTo": null,
#                 "rank": 0,
#                 "valid": true,
#                 "externalcode": []
#               }
#             ],
#             "validationrule": [
#               {
#                 "regularExpression": "Überweisung",
#                 "min": null,
#                 "max": null,
#                 "expectedValidationResult": true,
#                 "validationFailureMessage": "Für Firmen ist nur Überweisung zulässig",
#                 "validationFailureI18N": null,
#                 "minDate": null,
#                 "maxDate": null,
#                 "stepwise": null,
#                 "minLength": null,
#                 "maxLength": null
#               }
#             ],
#             "aspect": [
#               "SelfActive Erfassung",
#               "TouchActive Erfassung",
#               "CollActive Erfassung"
#             ],
#             "evaluation": [],
#             "externalcode": []
#           },
#           {
#             "attributeId": 379,
#             "productVariantAttributeId": 3850,
#             "name": "Zahlungsweise",
#             "displayName": "Zahlungsweise",
#             "displayDescription": "",
#             "catName": "Zahlungsinformationen",
#             "catDisplayName": "Zahlungsinformationen",
#             "catRank": 200,
#             "attributeCategoryId": 11,
#             "placeholder": null,
#             "description": "",
#             "type": "Liste",
#             "typeId": -102014,
#             "value": "einmalig",
#             "inputField": true,
#             "hide": true,
#             "advanced": false,
#             "dynamicLoaderId": null,
#             "productVariantId": 64,
#             "productName": "FirmenSchutzbrief (Standardtarif)",
#             "personAttributeTypeId": null,
#             "documentAttributeTypeId": null,
#             "businessObjectAttributeTypeId": null,
#             "required": false,
#             "rank": 200,
#             "listId": -51,
#             "properties": {},
#             "autocomplete": null,
#             "autofocus": null,
#             "readonly": null,
#             "size": null,
#             "min": null,
#             "max": null,
#             "minDate": null,
#             "maxDate": null,
#             "minLength": null,
#             "maxLength": null,
#             "placeholderDpva": "",
#             "stepwise": null,
#             "aspectDisplayNames": {},
#             "listelement": [
#               {
#                 "listelementId": -5105,
#                 "name": "einmalig",
#                 "description": "",
#                 "availableFrom": null,
#                 "availableTo": null,
#                 "rank": 0,
#                 "valid": true,
#                 "externalcode": []
#               }
#             ],
#             "validationrule": [
#               {
#                 "regularExpression": "einmalig",
#                 "min": null,
#                 "max": null,
#                 "expectedValidationResult": true,
#                 "validationFailureMessage": "Nur Einmalzahlung zulässig",
#                 "validationFailureI18N": null,
#                 "minDate": null,
#                 "maxDate": null,
#                 "stepwise": null,
#                 "minLength": null,
#                 "maxLength": null
#               }
#             ],
#             "aspect": [
#               "SelfActive Erfassung",
#               "TouchActive Erfassung",
#               "CollActive Erfassung"
#             ],
#             "evaluation": [],
#             "externalcode": []
#           }
#         ]
#       }
#     ],
#     "subproduct": [
#       {
#         "productTreeRenderData": {
#           "product": {
#             "productId": 19,
#             "productVariantId": 19,
#             "name": "Kunde",
#             "description": "Firmenkunde V01",
#             "versionInfo": "Firmenkunde V01",
#             "displayName": "Vertragsnehmer",
#             "tooltip": null,
#             "state": "Entwurf",
#             "typeId": -2101,
#             "availableFrom": 1611021600000,
#             "availableTo": null,
#             "personSpecific": false,
#             "providerId": 4,
#             "providerName": "SCHUTZGARANT",
#             "providerShortName": "",
#             "tag": [],
#             "tagrenderdata": null,
#             "rule": [],
#             "externalcode": []
#           },
#           "attributecategorie": [
#             {
#               "name": "Personendaten",
#               "displayName": "Personendaten",
#               "rank": 200,
#               "expandable": false,
#               "collapse": null,
#               "header": "",
#               "footer": "",
#               "displayAttributeCategoryDtoMap": {
#                 "TouchActive Kunde": {
#                   "collapse": null,
#                   "header": "",
#                   "footer": ""
#                 },
#                 "SelfActive Erfassung": {
#                   "collapse": null,
#                   "header": "",
#                   "footer": ""
#                 },
#                 "Eingabedaten": {
#                   "collapse": null,
#                   "header": "",
#                   "footer": ""
#                 }
#               },
#               "attribute": [
#                 {
#                   "attributeId": 34,
#                   "productVariantAttributeId": 67,
#                   "name": "Anrede (Person)",
#                   "displayName": "Anrede",
#                   "displayDescription": "",
#                   "catName": "Personendaten",
#                   "catDisplayName": "Personendaten",
#                   "catRank": 200,
#                   "attributeCategoryId": 14,
#                   "placeholder": null,
#                   "description": "",
#                   "type": "Liste",
#                   "typeId": -102014,
#                   "value": "Firma",
#                   "inputField": false,
#                   "hide": false,
#                   "advanced": true,
#                   "dynamicLoaderId": null,
#                   "productVariantId": 19,
#                   "productName": "Kunde",
#                   "personAttributeTypeId": -2139095038,
#                   "documentAttributeTypeId": null,
#                   "businessObjectAttributeTypeId": null,
#                   "required": false,
#                   "rank": 100,
#                   "listId": -2,
#                   "properties": {},
#                   "autocomplete": false,
#                   "autofocus": false,
#                   "readonly": false,
#                   "size": null,
#                   "min": null,
#                   "max": null,
#                   "minDate": null,
#                   "maxDate": null,
#                   "minLength": null,
#                   "maxLength": null,
#                   "placeholderDpva": "",
#                   "stepwise": null,
#                   "aspectDisplayNames": {},
#                   "listelement": [
#                     {
#                       "listelementId": -31,
#                       "name": "Herr",
#                       "description": "Anrede Herr",
#                       "availableFrom": null,
#                       "availableTo": null,
#                       "rank": 2,
#                       "valid": true,
#                       "externalcode": []
#                     },
#                     {
#                       "listelementId": -32,
#                       "name": "Frau",
#                       "description": "Anrede Frau",
#                       "availableFrom": null,
#                       "availableTo": null,
#                       "rank": 3,
#                       "valid": true,
#                       "externalcode": []
#                     },
#                     {
#                       "listelementId": -30,
#                       "name": "Firma",
#                       "description": "Anrede Firma",
#                       "availableFrom": null,
#                       "availableTo": null,
#                       "rank": 4,
#                       "valid": true,
#                       "externalcode": []
#                     },
#                     {
#                       "listelementId": -39,
#                       "name": "Divers",
#                       "description": "Anrede Divers",
#                       "availableFrom": null,
#                       "availableTo": null,
#                       "rank": 9,
#                       "valid": true,
#                       "externalcode": []
#                     }
#                   ],
#                   "validationrule": null,
#                   "aspect": [
#                     "SelfActive Erfassung",
#                     "TouchActive Kunde"
#                   ],
#                   "evaluation": [],
#                   "externalcode": []
#                 },
#                 {
#                   "attributeId": 31,
#                   "productVariantAttributeId": 64,
#                   "name": "Nachname (Person)",
#                   "displayName": "Firmenname",
#                   "displayDescription": "",
#                   "catName": "Personendaten",
#                   "catDisplayName": "Personendaten",
#                   "catRank": 200,
#                   "attributeCategoryId": 14,
#                   "placeholder": null,
#                   "description": "",
#                   "type": "Text",
#                   "typeId": -102009,
#                   "value": "",
#                   "inputField": true,
#                   "hide": false,
#                   "advanced": false,
#                   "dynamicLoaderId": null,
#                   "productVariantId": 19,
#                   "productName": "Kunde",
#                   "personAttributeTypeId": -2139095036,
#                   "documentAttributeTypeId": null,
#                   "businessObjectAttributeTypeId": null,
#                   "required": true,
#                   "rank": 200,
#                   "listId": null,
#                   "properties": {
#                     "linebreak": "true",
#                     "optionalStyleClass": "radio-group info col-xs-12"
#                   },
#                   "autocomplete": null,
#                   "autofocus": null,
#                   "readonly": null,
#                   "size": null,
#                   "min": null,
#                   "max": null,
#                   "minDate": null,
#                   "maxDate": null,
#                   "minLength": null,
#                   "maxLength": null,
#                   "placeholderDpva": "",
#                   "stepwise": null,
#                   "aspectDisplayNames": {},
#                   "listelement": null,
#                   "validationrule": [],
#                   "aspect": [
#                     "SelfActive Erfassung",
#                     "TouchActive Kunde"
#                   ],
#                   "evaluation": [],
#                   "externalcode": []
#                 },
#                 {
#                   "attributeId": 124,
#                   "productVariantAttributeId": 226,
#                   "name": "Firmenanschrift (Firmenanschrift)",
#                   "displayName": "Anschrift",
#                   "displayDescription": "",
#                   "catName": "Personendaten",
#                   "catDisplayName": "Personendaten",
#                   "catRank": 200,
#                   "attributeCategoryId": 14,
#                   "placeholder": null,
#                   "description": "",
#                   "type": "Autocomplete Adresse",
#                   "typeId": -102164,
#                   "value": "",
#                   "inputField": true,
#                   "hide": false,
#                   "advanced": false,
#                   "dynamicLoaderId": null,
#                   "productVariantId": 19,
#                   "productName": "Kunde",
#                   "personAttributeTypeId": -226492405,
#                   "documentAttributeTypeId": null,
#                   "businessObjectAttributeTypeId": null,
#                   "required": true,
#                   "rank": 210,
#                   "listId": null,
#                   "properties": {},
#                   "autocomplete": null,
#                   "autofocus": null,
#                   "readonly": null,
#                   "size": null,
#                   "min": null,
#                   "max": null,
#                   "minDate": null,
#                   "maxDate": null,
#                   "minLength": null,
#                   "maxLength": null,
#                   "placeholderDpva": "",
#                   "stepwise": null,
#                   "aspectDisplayNames": {},
#                   "listelement": null,
#                   "validationrule": [],
#                   "aspect": [
#                     "SelfActive Erfassung",
#                     "TouchActive Kunde"
#                   ],
#                   "evaluation": [],
#                   "externalcode": []
#                 }
#               ]
#             },
#             {
#               "name": "Kontaktdaten",
#               "displayName": "Kontaktdaten",
#               "rank": 400,
#               "expandable": false,
#               "collapse": null,
#               "header": "",
#               "footer": "",
#               "displayAttributeCategoryDtoMap": {
#                 "TouchActive Kunde": {
#                   "collapse": null,
#                   "header": "",
#                   "footer": ""
#                 },
#                 "SelfActive Erfassung": {
#                   "collapse": null,
#                   "header": "",
#                   "footer": ""
#                 },
#                 "Eingabedaten": {
#                   "collapse": null,
#                   "header": "",
#                   "footer": ""
#                 },
#                 "Vertragsvorlage": {
#                   "collapse": null,
#                   "header": "",
#                   "footer": ""
#                 }
#               },
#               "attribute": [
#                 {
#                   "attributeId": 49,
#                   "productVariantAttributeId": 82,
#                   "name": "E-Mail (Kontaktweg)",
#                   "displayName": "E-Mail Firma",
#                   "displayDescription": "",
#                   "catName": "Kontaktdaten",
#                   "catDisplayName": "Kontaktdaten",
#                   "catRank": 400,
#                   "attributeCategoryId": 20,
#                   "placeholder": null,
#                   "description": "",
#                   "type": "E-Mail",
#                   "typeId": -102170,
#                   "value": "",
#                   "inputField": true,
#                   "hide": false,
#                   "advanced": false,
#                   "dynamicLoaderId": null,
#                   "productVariantId": 19,
#                   "productName": "Kunde",
#                   "personAttributeTypeId": -1870659561,
#                   "documentAttributeTypeId": null,
#                   "businessObjectAttributeTypeId": null,
#                   "required": true,
#                   "rank": 100,
#                   "listId": null,
#                   "properties": {
#                     "linebreak": "true"
#                   },
#                   "autocomplete": null,
#                   "autofocus": null,
#                   "readonly": null,
#                   "size": null,
#                   "min": null,
#                   "max": null,
#                   "minDate": null,
#                   "maxDate": null,
#                   "minLength": null,
#                   "maxLength": null,
#                   "placeholderDpva": "",
#                   "stepwise": null,
#                   "aspectDisplayNames": {},
#                   "listelement": null,
#                   "validationrule": [
#                     {
#                       "regularExpression": "^[^-\\~\\*\\s][\\wäÄöÖüÜ\\+\\-\\.]*@([\\w-]+\\.)+[\\w-]{2,}$",
#                       "min": null,
#                       "max": null,
#                       "expectedValidationResult": true,
#                       "validationFailureMessage": "Ungültige E-Mail-Adresse",
#                       "validationFailureI18N": null,
#                       "minDate": null,
#                       "maxDate": null,
#                       "stepwise": null,
#                       "minLength": null,
#                       "maxLength": null
#                     }
#                   ],
#                   "aspect": [
#                     "SelfActive Erfassung",
#                     "TouchActive Kunde"
#                   ],
#                   "evaluation": [],
#                   "externalcode": []
#                 },
#                 {
#                   "attributeId": 52,
#                   "productVariantAttributeId": 85,
#                   "name": "Telefon Festnetz (Kontaktweg)",
#                   "displayName": "Telefon 1",
#                   "displayDescription": "",
#                   "catName": "Kontaktdaten",
#                   "catDisplayName": "Kontaktdaten",
#                   "catRank": 400,
#                   "attributeCategoryId": 20,
#                   "placeholder": null,
#                   "description": "",
#                   "type": "Telefon",
#                   "typeId": -102171,
#                   "value": "",
#                   "inputField": true,
#                   "hide": false,
#                   "advanced": false,
#                   "dynamicLoaderId": null,
#                   "productVariantId": 19,
#                   "productName": "Kunde",
#                   "personAttributeTypeId": -1870659564,
#                   "documentAttributeTypeId": null,
#                   "businessObjectAttributeTypeId": null,
#                   "required": true,
#                   "rank": 200,
#                   "listId": null,
#                   "properties": {},
#                   "autocomplete": null,
#                   "autofocus": null,
#                   "readonly": null,
#                   "size": null,
#                   "min": null,
#                   "max": null,
#                   "minDate": null,
#                   "maxDate": null,
#                   "minLength": null,
#                   "maxLength": null,
#                   "placeholderDpva": "",
#                   "stepwise": null,
#                   "aspectDisplayNames": {},
#                   "listelement": null,
#                   "validationrule": [],
#                   "aspect": [
#                     "SelfActive Erfassung",
#                     "TouchActive Kunde"
#                   ],
#                   "evaluation": [],
#                   "externalcode": []
#                 },
#                 {
#                   "attributeId": 55,
#                   "productVariantAttributeId": 88,
#                   "name": "Telefon Mobil (Kontaktweg)",
#                   "displayName": "Telefon 2",
#                   "displayDescription": "",
#                   "catName": "Kontaktdaten",
#                   "catDisplayName": "Kontaktdaten",
#                   "catRank": 400,
#                   "attributeCategoryId": 20,
#                   "placeholder": null,
#                   "description": "",
#                   "type": "Telefon",
#                   "typeId": -102171,
#                   "value": "",
#                   "inputField": true,
#                   "hide": false,
#                   "advanced": false,
#                   "dynamicLoaderId": null,
#                   "productVariantId": 19,
#                   "productName": "Kunde",
#                   "personAttributeTypeId": -1870659563,
#                   "documentAttributeTypeId": null,
#                   "businessObjectAttributeTypeId": null,
#                   "required": false,
#                   "rank": 300,
#                   "listId": null,
#                   "properties": {},
#                   "autocomplete": null,
#                   "autofocus": null,
#                   "readonly": null,
#                   "size": null,
#                   "min": null,
#                   "max": null,
#                   "minDate": null,
#                   "maxDate": null,
#                   "minLength": null,
#                   "maxLength": null,
#                   "placeholderDpva": "",
#                   "stepwise": null,
#                   "aspectDisplayNames": {},
#                   "listelement": null,
#                   "validationrule": [],
#                   "aspect": [
#                     "SelfActive Erfassung",
#                     "TouchActive Kunde"
#                   ],
#                   "evaluation": [],
#                   "externalcode": []
#                 }
#               ]
#             }
#           ],
#           "subproduct": []
#         },
#         "mandatory": false,
#         "minCount": 1,
#         "maxCount": 1,
#         "bundleProductId": 40,
#         "partProductVariantId": 19,
#         "bundleProductVariantId": 64,
#         "rank": 10
#       },
#       {
#         "productTreeRenderData": {
#           "product": {
#             "productId": 3061,
#             "productVariantId": 3112,
#             "name": "Ansprechpartner",
#             "description": "Ansprechpartner V01",
#             "versionInfo": "Ansprechpartner V01",
#             "displayName": "Ansprechpartner",
#             "tooltip": null,
#             "state": "Entwurf",
#             "typeId": -101007,
#             "availableFrom": null,
#             "availableTo": null,
#             "personSpecific": false,
#             "providerId": 4,
#             "providerName": "SCHUTZGARANT",
#             "providerShortName": "",
#             "tag": [],
#             "tagrenderdata": null,
#             "rule": [],
#             "externalcode": []
#           },
#           "attributecategorie": [
#             {
#               "name": "Personendaten",
#               "displayName": "Personendaten",
#               "rank": 200,
#               "expandable": false,
#               "collapse": null,
#               "header": "",
#               "footer": "",
#               "displayAttributeCategoryDtoMap": {
#                 "TouchActive Kunde": {
#                   "collapse": null,
#                   "header": "",
#                   "footer": ""
#                 },
#                 "SelfActive Erfassung": {
#                   "collapse": null,
#                   "header": "",
#                   "footer": ""
#                 },
#                 "Eingabedaten": {
#                   "collapse": null,
#                   "header": "",
#                   "footer": ""
#                 }
#               },
#               "attribute": [
#                 {
#                   "attributeId": 403,
#                   "productVariantAttributeId": 3979,
#                   "name": "Vorname",
#                   "displayName": "Vorname",
#                   "displayDescription": null,
#                   "catName": "Personendaten",
#                   "catDisplayName": "Personendaten",
#                   "catRank": 200,
#                   "attributeCategoryId": 14,
#                   "placeholder": null,
#                   "description": null,
#                   "type": "Text",
#                   "typeId": -102009,
#                   "value": null,
#                   "inputField": true,
#                   "hide": false,
#                   "advanced": false,
#                   "dynamicLoaderId": null,
#                   "productVariantId": 3112,
#                   "productName": "Ansprechpartner",
#                   "personAttributeTypeId": null,
#                   "documentAttributeTypeId": null,
#                   "businessObjectAttributeTypeId": null,
#                   "required": false,
#                   "rank": 100,
#                   "listId": null,
#                   "properties": {},
#                   "autocomplete": null,
#                   "autofocus": null,
#                   "readonly": null,
#                   "size": null,
#                   "min": null,
#                   "max": null,
#                   "minDate": null,
#                   "maxDate": null,
#                   "minLength": null,
#                   "maxLength": null,
#                   "placeholderDpva": null,
#                   "stepwise": null,
#                   "aspectDisplayNames": {},
#                   "listelement": null,
#                   "validationrule": [],
#                   "aspect": [
#                     "SelfActive Erfassung"
#                   ],
#                   "evaluation": [],
#                   "externalcode": []
#                 },
#                 {
#                   "attributeId": 400,
#                   "productVariantAttributeId": 3976,
#                   "name": "Name",
#                   "displayName": "Name",
#                   "displayDescription": null,
#                   "catName": "Personendaten",
# ...
#                       "availableTo": null,
#                       "rank": 6500,
#                       "valid": true,
#                       "externalcode": []
#                     },
#                     {
#                       "listelementId": 300364,
#                       "name": "Oranier",
#                       "description": null,
#                       "availableFrom": null,
#                       "availableTo": null,
#                       "rank": 6600,
#                       "valid": true,
#                       "externalcode": []
#                     },
#                     {
#                       "listelementId": 300133,
#                       "name": "Panasonic",
#                       "description": null,
#                       "availableFrom": null,
#                       "availableTo": null,
#                       "rank": 6700,
#                       "valid": true,
#                       "externalcode": []
#                     },
#                     {
#                       "listelementId": 300366,
#                       "name": "PEAQ",
#                       "description": null,
#                       "availableFrom": null,
#                       "availableTo": null,
#                       "rank": 6800,
#                       "valid": true,
#                       "externalcode": []
#                     },
#                     {
#                       "listelementId": 300368,
#                       "name": "Privileg",
#                       "description": null,
#                       "availableFrom": null,
#                       "availableTo": null,
#                       "rank": 6900,
#                       "valid": true,
#                       "externalcode": []
#                     },
#                     {
#                       "listelementId": 300370,
#                       "name": "Progress",
#                       "description": null,
#                       "availableFrom": null,
#                       "availableTo": null,
#                       "rank": 7000,
#                       "valid": true,
#                       "externalcode": []
#                     },
#                     {
#                       "listelementId": 300372,
#                       "name": "Schaub Lorenz",
#                       "description": null,
#                       "availableFrom": null,
#                       "availableTo": null,
#                       "rank": 7200,
#                       "valid": true,
#                       "externalcode": []
#                     },
#                     {
#                       "listelementId": 300374,
#                       "name": "Sharp",
#                       "description": null,
#                       "availableFrom": null,
#                       "availableTo": null,
#                       "rank": 7300,
#                       "valid": true,
#                       "externalcode": []
#                     },
#                     {
#                       "listelementId": 300376,
#                       "name": "Sibir",
#                       "description": null,
#                       "availableFrom": null,
#                       "availableTo": null,
#                       "rank": 7400,
#                       "valid": true,
#                       "externalcode": []
#                     },
#                     {
#                       "listelementId": 300378,
#                       "name": "Siemens",
#                       "description": null,
#                       "availableFrom": null,
#                       "availableTo": null,
#                       "rank": 7500,
#                       "valid": true,
#                       "externalcode": []
#                     },
#                     {
#                       "listelementId": 300380,
#                       "name": "Smeg",
#                       "description": null,
#                       "availableFrom": null,
#                       "availableTo": null,
#                       "rank": 7600,
#                       "valid": true,
#                       "externalcode": []
#                     },
#                     {
#                       "listelementId": 300136,
#                       "name": "Sony",
#                       "description": null,
#                       "availableFrom": null,
#                       "availableTo": null,
#                       "rank": 7800,
#                       "valid": true,
#                       "externalcode": []
#                     },
#                     {
#                       "listelementId": 300382,
#                       "name": "Teka",
#                       "description": null,
#                       "availableFrom": null,
#                       "availableTo": null,
#                       "rank": 7900,
#                       "valid": true,
#                       "externalcode": []
#                     },
#                     {
#                       "listelementId": 300384,
#                       "name": "Termikel",
#                       "description": null,
#                       "availableFrom": null,
#                       "availableTo": null,
#                       "rank": 8000,
#                       "valid": true,
#                       "externalcode": []
#                     },
#                     {
#                       "listelementId": 300141,
#                       "name": "UleFone",
#                       "description": null,
#                       "availableFrom": null,
#                       "availableTo": null,
#                       "rank": 8100,
#                       "valid": true,
#                       "externalcode": []
#                     },
#                     {
#                       "listelementId": 300142,
#                       "name": "Vivo",
#                       "description": null,
#                       "availableFrom": null,
#                       "availableTo": null,
#                       "rank": 8200,
#                       "valid": true,
#                       "externalcode": []
#                     },
#                     {
#                       "listelementId": 300386,
#                       "name": "Whirlpool",
#                       "description": null,
#                       "availableFrom": null,
#                       "availableTo": null,
#                       "rank": 8300,
#                       "valid": true,
#                       "externalcode": []
#                     },
#                     {
#                       "listelementId": 300143,
#                       "name": "Wiko",
#                       "description": null,
#                       "availableFrom": null,
#                       "availableTo": null,
#                       "rank": 8400,
#                       "valid": true,
#                       "externalcode": []
#                     },
#                     {
#                       "listelementId": 300388,
#                       "name": "Zanker",
#                       "description": null,
#                       "availableFrom": null,
#                       "availableTo": null,
#                       "rank": 8600,
#                       "valid": true,
#                       "externalcode": []
#                     },
#                     {
#                       "listelementId": 300390,
#                       "name": "Zanussi",
#                       "description": null,
#                       "availableFrom": null,
#                       "availableTo": null,
#                       "rank": 8700,
#                       "valid": true,
#                       "externalcode": []
#                     },
#                     {
#                       "listelementId": 500131,
#                       "name": "ZTE",
#                       "description": null,
#                       "availableFrom": null,
#                       "availableTo": null,
#                       "rank": 8800,
#                       "valid": true,
#                       "externalcode": []
#                     },
#                     {
#                       "listelementId": 300067,
#                       "name": "Sonstige",
#                       "description": null,
#                       "availableFrom": null,
#                       "availableTo": null,
#                       "rank": 999999,
#                       "valid": true,
#                       "externalcode": []
#                     }
#                   ],
#                   "validationrule": [],
#                   "aspect": [
#                     "SelfActive Erfassung",
#                     "TouchActive Erfassung",
#                     "CollActive Erfassung"
#                   ],
#                   "evaluation": [],
#                   "externalcode": []
#                 },
#                 {
#                   "attributeId": 217,
#                   "productVariantAttributeId": 19093,
#                   "name": "Herstellername",
#                   "displayName": "Herstellername",
#                   "displayDescription": "",
#                   "catName": "Gerätedaten",
#                   "catDisplayName": "Gerätedaten",
#                   "catRank": 500,
#                   "attributeCategoryId": 23,
#                   "placeholder": null,
#                   "description": "",
#                   "type": "Text",
#                   "typeId": -102009,
#                   "value": "",
#                   "inputField": true,
#                   "hide": false,
#                   "advanced": false,
#                   "dynamicLoaderId": null,
#                   "productVariantId": 3649,
#                   "productName": "Versicherte Geräte",
#                   "personAttributeTypeId": null,
#                   "documentAttributeTypeId": null,
#                   "businessObjectAttributeTypeId": null,
#                   "required": false,
#                   "rank": 510,
#                   "listId": null,
#                   "properties": {},
#                   "autocomplete": null,
#                   "autofocus": null,
#                   "readonly": null,
#                   "size": null,
#                   "min": null,
#                   "max": null,
#                   "minDate": null,
#                   "maxDate": null,
#                   "minLength": null,
#                   "maxLength": null,
#                   "placeholderDpva": "",
#                   "stepwise": null,
#                   "aspectDisplayNames": {},
#                   "listelement": null,
#                   "validationrule": [],
#                   "aspect": [
#                     "SelfActive Erfassung",
#                     "TouchActive Erfassung",
#                     "CollActive Erfassung"
#                   ],
#                   "evaluation": [
#                     {
#                       "productVariantAttributeId": 19093,
#                       "source": 19087,
#                       "valueRegEx": "(Sonstige|300067)",
#                       "groupName": "",
#                       "required": true,
#                       "display": true,
#                       "validationRuleRegEx": null
#                     }
#                   ],
#                   "externalcode": []
#                 },
#                 {
#                   "attributeId": 130,
#                   "productVariantAttributeId": 19090,
#                   "name": "Modell",
#                   "displayName": "Modell",
#                   "displayDescription": "Geben Sie hier bitte das Modell / Bezeichnung des Gerätes mit an.",
#                   "catName": "Gerätedaten",
#                   "catDisplayName": "Gerätedaten",
#                   "catRank": 500,
#                   "attributeCategoryId": 23,
#                   "placeholder": null,
#                   "description": "Geben Sie hier bitte das Modell / Bezeichnung des Gerätes mit an.",
#                   "type": "Text",
#                   "typeId": -102009,
#                   "value": "",
#                   "inputField": true,
#                   "hide": false,
#                   "advanced": false,
#                   "dynamicLoaderId": null,
#                   "productVariantId": 3649,
#                   "productName": "Versicherte Geräte",
#                   "personAttributeTypeId": null,
#                   "documentAttributeTypeId": null,
#                   "businessObjectAttributeTypeId": null,
#                   "required": true,
#                   "rank": 600,
#                   "listId": null,
#                   "properties": {},
#                   "autocomplete": null,
#                   "autofocus": null,
#                   "readonly": null,
#                   "size": null,
#                   "min": null,
#                   "max": null,
#                   "minDate": null,
#                   "maxDate": null,
#                   "minLength": null,
#                   "maxLength": null,
#                   "placeholderDpva": "",
#                   "stepwise": null,
#                   "aspectDisplayNames": {},
#                   "listelement": null,
#                   "validationrule": [
#                     {
#                       "regularExpression": ".{0,40}",
#                       "min": null,
#                       "max": null,
#                       "expectedValidationResult": true,
#                       "validationFailureMessage": "Der Modellname darf nicht länger als 40 Zeichen sein.",
#                       "validationFailureI18N": null,
#                       "minDate": null,
#                       "maxDate": null,
#                       "stepwise": null,
#                       "minLength": null,
#                       "maxLength": null
#                     }
#                   ],
#                   "aspect": [
#                     "SelfActive Erfassung",
#                     "TouchActive Erfassung",
#                     "CollActive Erfassung"
#                   ],
#                   "evaluation": [],
#                   "externalcode": []
#                 },
#                 {
#                   "attributeId": 16,
#                   "productVariantAttributeId": 19099,
#                   "name": "Herstellergarantie (Monate)",
#                   "displayName": "Herstellergarantie (Monate)",
#                   "displayDescription": "Geben Sie hier bitte die Hersteller Garantielaufzeitzeit ein, die Sie beim Kauf des Gerätes erhalten haben (Mindestens 12 Monate).\r\n",
#                   "catName": "Gerätedaten",
#                   "catDisplayName": "Gerätedaten",
#                   "catRank": 500,
#                   "attributeCategoryId": 23,
#                   "placeholder": null,
#                   "description": "Geben Sie hier bitte die Hersteller Garantielaufzeitzeit ein, die Sie beim Kauf des Gerätes erhalten haben (Mindestens 12 Monate).\r\n",
#                   "type": "Zahl",
#                   "typeId": -102011,
#                   "value": "24",
#                   "inputField": true,
#                   "hide": false,
#                   "advanced": false,
#                   "dynamicLoaderId": null,
#                   "productVariantId": 3649,
#                   "productName": "Versicherte Geräte",
#                   "personAttributeTypeId": null,
#                   "documentAttributeTypeId": null,
#                   "businessObjectAttributeTypeId": null,
#                   "required": true,
#                   "rank": 700,
#                   "listId": null,
#                   "properties": {},
#                   "autocomplete": null,
#                   "autofocus": null,
#                   "readonly": null,
#                   "size": null,
#                   "min": null,
#                   "max": null,
#                   "minDate": null,
#                   "maxDate": null,
#                   "minLength": null,
#                   "maxLength": null,
#                   "placeholderDpva": "",
#                   "stepwise": null,
#                   "aspectDisplayNames": {},
#                   "listelement": null,
#                   "validationrule": [],
#                   "aspect": [
#                     "SelfActive Erfassung"
#                   ],
#                   "evaluation": [],
#                   "externalcode": []
#                 }
#               ]
#             }
#           ],
#           "subproduct": []
#         },
#         "mandatory": false,
#         "minCount": 1,
#         "maxCount": 1,
#         "bundleProductId": 5107,
#         "partProductVariantId": 3649,
#         "bundleProductVariantId": 3610,
#         "rank": 200
#       }
#     ]
#   }
# ]

# %%
from pydantic import BaseModel, Field, ValidationError, model_validator, field_validator
from typing import Optional, List

class PaymentProvider(BaseModel):
    providerType: int = Field(..., description="Type of payment service provider. Possible values: -160 = Credit card, -161 = Bank, -162 = Amazon Pay, -163 = PayPal, -165 = Google Pay")
    providerNumber: Optional[str] = Field(None, description="BIC of the bank, necessary for intern'ational accounts only")
    providerName: Optional[str] = Field(None, description="Possible values: Name of bank, 'VISA', 'AMEX', ...")
    accountNumber: Optional[str] = Field(None, description="IBAN, credit card number or payment id (associated email for online payment services)")
    accountOwner: Optional[str] = Field(None, description="Name of account owner")
    expirationDate: Optional[str] = Field(None, description="Needed when providerType=-160")

    @model_validator(mode="after")
    def check_fields(self):
        ptype = getattr(self, 'providerType')
        if ptype == -160: 
            required = ['providerName', 'accountNumber', 'accountOwner', 'expirationDate']
        elif ptype == -161:
            required = ['providerNumber', 'accountNumber', 'accountOwner']
        elif ptype < -161 and ptype > -166:
            required = ['accountNumber']
        else:
            raise ValueError(f"ProviderType {ptype} unknown. Possible values: -160 = Credit card, -161 = Bank, -162 = Amazon Pay, -163 = PayPal, -165 = Google Pay")

        missing = [f for f in required if not getattr(self, f)]
        if missing:
            raise ValueError(f"Missing required fields for providerType {ptype}: {', '.join(missing)}")
        return self

class Address(BaseModel):
    typeId: int = Field(..., description="Address type. -10 = Private, -11 = Business, -12 = Billing, -13 = Delivery")
    street: str = Field(..., description="Street (without house number)")
    streetNumber: str = Field(..., description="House number")
    addition: Optional[str] = Field(None, description="Additional info (e.g. '2nd floor')")
    zipcode: str = Field(..., description="Postal code")
    city: str = Field(..., description="City name")
    countryCode: str = Field(..., min_length=2, max_length=2, description="2-char ISO country code (e.g. DE)")

class ContactInfo(BaseModel):
    typeId: int = Field(..., description="Contact type. -21=Mobile, -20=Landline, -23=Email, -22=Fax")
    value: str = Field(..., description="Contact value: phone/email/etc.")

class Person(BaseModel):
    typeId: int = Field(..., description="Person type: -2101 main, -30 company")
    salutationId: Optional[int] = Field(None, description="Salutation ID, required for individuals")
    title: Optional[str] = Field(None, description="Title such as Dr., Prof., etc.")
    firstName: Optional[str] = Field(None, description="First name. Not for companies.")
    lastName: str = Field(..., description="Last name or company name")
    dateOfBirth: Optional[str] = Field(None, description="Date of birth (YYYY-MM-DD)", pattern="^\\d{4}-\\d{2}-\\d{2}$")
    addresses: List[Address] = Field(default_factory=list, description="Addresses of the person")
    contactInformations: List[ContactInfo] = Field(default_factory=list, description="Contact info (phone, email, etc.)")

    @model_validator(mode="before")
    @classmethod
    def check_lists(cls, data):
        errors = []
        if "addresses" in data and not isinstance(data["addresses"], list):
            errors.append(f"addresses must be a list, got {type(data['addresses']).__name__} ({data['addresses']!r})")
        if "contactInformations" in data and not isinstance(data["contactInformations"], list):
            errors.append(f"contactInformations must be a list, got {type(data['contactInformations']).__name__} ({data['contactInformations']!r})")
        if errors:
            raise TypeError("; ".join(errors))
        return data

    @model_validator(mode="after")
    def check_fields(self):
        # Company or person?
        if self.typeId == -30:  # Company
            # Only lastName (company name) required
            if not self.lastName:
                raise ValueError("lastName (company name) required for companies.")
        else:
            # Person: salutationId, firstName, lastName required
            missing = []
            if not self.salutationId:
                missing.append("salutationId")
            if not self.firstName:
                missing.append("firstName")
            if not self.lastName:
                missing.append("lastName")
            if missing:
                raise ValueError(f"Missing required fields for person: {', '.join(missing)}")
        return self


# print(json.dumps(PaymentProvider.model_json_schema(), indent=2))

# %% [markdown]
# ## Testing Payment

# %%
try:
    ## Testing Credit Card
    provider = PaymentProvider(providerType=-160, providerName="AMEX", accountNumber="1234-4567", accountOwner="Jane Doe", expirationDate="1.1.2026")
    # PaymentProvider(providerType=-160, providerName="AMEX", accountNumber="1234-4567", accountOwner="Jane Doe")
    ## Testing Bank
    # PaymentProvider(providerType=-161, providerNumber="BIC123", providerName="MyBank", accountNumber="DE123456789", accountOwner="Jane Doe")
    # PaymentProvider(providerType=-161, accountNumber="DE123456789", accountOwner="Jane Doe")
    # PaymentProvider(providerType=-161, accountNumber="DE123456789")
    ## Testing PayPal
    # PaymentProvider(providerType=-163, accountNumber="a@bc.de")
    # PaymentProvider(providerType=-161)
    ## Testing illegal payment provider
    # PaymentProvider(providerType=-166, accountNumber="DE123456789")
    print(dict(provider))

except ValidationError as e:
    print(e)
# Out:
# {'providerType': -160, 'providerNumber': None, 'providerName': 'AMEX', 'accountNumber': '1234-4567', 'accountOwner': 'Jane Doe', 'expirationDate': '1.1.2026'}

# %% [markdown]
# ## Testing Person

# %%
try:
    ## Correct info for corporate account 
    # Person(
    #     typeId=-30,
    #     lastName="ACME GmbH",
    #     addresses=[Address(typeId=-11, street="Hauptstr.", streetNumber="1", zipcode="12345", city="Berlin", countryCode="DE")],
    #     contactInformations=[ContactInfo(typeId=-23, value="info@acme.de")]
    # )
    ## Incorrect info for corporate account (country code missing in address)
    # Person(
    #     typeId=-30,
    #     lastName="ACME GmbH",
    #     addresses=[Address(typeId=-11, street="Hauptstr.", streetNumber="1", zipcode="12345", city="Berlin")],
    #     contactInformations=[ContactInfo(typeId=-23, value="info@acme.de")]
    # )
    ## Correct info for private account 
    # Person(
    #     typeId=-2101,
    #     salutationId=-31,
    #     firstName="Max",
    #     lastName="Mustermann",
    #     addresses=[Address(typeId=-10, street="Musterweg", streetNumber="2", zipcode="54321", city="Musterstadt", countryCode="DE")],
    #     contactInformations=[ContactInfo(typeId=-23, value="max@mustermann.de")]
    # )    
    ## Incorrect info for private account (addresses no a list)
    Person(
        typeId=-2101,
        salutationId=-31,
        firstName="Max",
        lastName="Mustermann",
        addresses=Address(typeId=-10, street="Musterweg", streetNumber="2", zipcode="54321", city="Musterstadt", countryCode="DE"),
        contactInformations=[ContactInfo(typeId=-23, value="max@mustermann.de")]
    )
except ValidationError as e:
    print(e)
except TypeError as e:
    print(e)
# Out:
# addresses must be a list, got Address (Address(typeId=-10, street='Musterweg', streetNumber='2', addition=None, zipcode='54321', city='Musterstadt', countryCode='DE'))

# %% [markdown]
# ## Defining Attributes

# %%
from typing import List, Optional, Union, Literal
from pydantic import BaseModel, Field, create_model

def generate_attribute_model(attributes):
    fields = {}

    for attr in attributes:

        if not (attr.get("inputField") is True and attr.get("hide") is False):
            continue
        
        field_name = str(attr.get("attributeId"))
        description = attr.get("displayName", "")
        attr_type = attr.get("type")
        required = attr.get("required", False)
        default = attr.get("value")

        # Determine the field type
        if attr_type == "Liste":
            # Add enum values to description
            if attr.get('listelement'):
                enum_values = ', '.join([val['name'] for val in attr.get('listelement')])
                description += f", enum values: {enum_values}"
            field_type = str
        elif attr_type == 'Zahl':
            field_type = int
        elif attr_type == 'Datum':
            field_type = str
            description += ", pattern: ^\\d{{4}}-\\d{{2}}-\\d{{2}}$"
        else:
            field_type = str

        # Handle optionality
        if not required:
            field_type = Optional[field_type]

        fields[field_name] = (field_type, Field(default, description=description))

    # Dynamically create model
    DynamicAttributes = create_model("DynamicAttributes", **fields)
    return DynamicAttributes

# %%
from pydantic import BaseModel, Field, create_model, constr, conint
from typing import Optional, Literal, Union
import re

from typing import Optional, Literal, get_args
from pydantic import create_model, Field, constr

def generate_attribute_model(model_name, attributes):
    fields = {}

    for attr in attributes:
        if not (attr.get("inputField") is True and attr.get("hide") is False):
            continue

        # Valid Python field name
        field_name = f'attribute_{attr["attributeId"]}'

        title = attr.get("displayName", "")
        description = ""
        attr_type = attr.get("type")
        required = attr.get("required", False)
        default = attr.get("value", None)
        
        # Choose field type and constraints
        if attr_type == "Liste":
            allowed = tuple(val['name'] for val in attr.get("listelement", []))
            field_type = Literal[allowed] if allowed else str
            description += f" (allowed: {', '.join(allowed)})"
        elif attr_type == "Zahl":
            field_type = int
            try:
              if default is not None:
                default= int(default)
            except:
                pass
            description += " (must be integer)"
        elif attr_type == "Datum":
            field_type = constr(pattern=r'^\d{4}-\d{2}-\d{2}$')
            description += " (YYYY-MM-DD)"
        elif attr_type == "Text":
            field_type = str
        elif attr_type == "Auswahl":
            field_type = bool
            try:
              if default is not None and isinstance(default, str):
                  default = (default.lower() == "true")
            except:
                pass
        else:
            field_type = str

        if not required:
            field_type = Optional[field_type]
            # Default to None if not set
            default = default if default is not None else None
        else:
            default = default if default is not None else ...

        fields[field_name] = (field_type, Field(title=title, description=description, default=default))

    return create_model(model_name, **fields)

# %%
print(json.dumps(data[1]['attributecategorie'],indent=2))
# Out:
# [
#   {
#     "name": "Allgemeine Kategorie",
#     "displayName": "Allgemeine Kategorie",
#     "rank": 30,
#     "expandable": false,
#     "collapse": null,
#     "header": "",
#     "footer": "",
#     "displayAttributeCategoryDtoMap": {
#       "Diebstahl": {
#         "collapse": null,
#         "header": "",
#         "footer": ""
#       },
#       "SelfActive Erfassung": {
#         "collapse": null,
#         "header": "",
#         "footer": ""
#       },
#       "Ger\u00e4teimport": {
#         "collapse": null,
#         "header": "",
#         "footer": ""
#       },
#       "Provisionierung": {
#         "collapse": null,
#         "header": "",
#         "footer": ""
#       },
#       "Vertrag": {
#         "collapse": null,
#         "header": "",
#         "footer": ""
#       },
#       "Vertragsvorlage": {
#         "collapse": null,
#         "header": "",
#         "footer": ""
#       },
#       "Beitragsberechnung": {
#         "collapse": null,
#         "header": "",
#         "footer": ""
#       },
#       "TouchActive Extra": {
#         "collapse": null,
#         "header": "",
#         "footer": ""
#       },
#       "Schaden": {
#         "collapse": null,
#         "header": "",
#         "footer": ""
#       },
#       "Vermittlermerkmale": {
#         "collapse": null,
#         "header": "",
#         "footer": ""
#       },
#       "Eingabedaten": {
#         "collapse": null,
#         "header": "",
#         "footer": ""
#       },
#       "Dokumentgenerierung": {
#         "collapse": null,
#         "header": "",
#         "footer": ""
#       },
#       "TouchActive Erfassung": {
#         "collapse": null,
#         "header": "",
#         "footer": ""
#       },
#       "Visuals": {
#         "collapse": null,
#         "header": "",
#         "footer": ""
#       }
#     },
#     "attribute": [
#       {
#         "attributeId": 331,
#         "productVariantAttributeId": 12853,
#         "name": "Ger\u00e4tetyp (privat)",
#         "displayName": "Ger\u00e4tetyp",
#         "displayDescription": "",
#         "catName": "Allgemeine Kategorie",
#         "catDisplayName": "Allgemeine Kategorie",
#         "catRank": 30,
#         "attributeCategoryId": -1,
#         "placeholder": null,
#         "description": "",
#         "type": "Liste",
#         "typeId": -102014,
#         "value": "Handy/Smartphone",
#         "inputField": true,
#         "hide": false,
#         "advanced": false,
#         "dynamicLoaderId": null,
#         "productVariantId": 3415,
#         "productName": "HandySchutzbrief Basis Check24",
#         "personAttributeTypeId": null,
#         "documentAttributeTypeId": null,
#         "businessObjectAttributeTypeId": null,
#         "required": true,
#         "rank": 100,
#         "listId": 25,
#         "properties": {},
#         "autocomplete": null,
#         "autofocus": null,
#         "readonly": null,
#         "size": null,
#         "min": null,
#         "max": null,
#         "minDate": null,
#         "maxDate": null,
#         "minLength": null,
#         "maxLength": null,
#         "placeholderDpva": "",
#         "stepwise": null,
#         "aspectDisplayNames": {},
#         "listelement": [
#           {
#             "listelementId": 500008,
#             "name": "Handy/Smartphone",
#             "description": null,
#             "availableFrom": null,
#             "availableTo": null,
#             "rank": 100,
#             "valid": true,
#             "externalcode": []
#           },
#           {
#             "listelementId": 500011,
#             "name": "Tablet",
#             "description": null,
#             "availableFrom": null,
#             "availableTo": null,
#             "rank": 200,
#             "valid": true,
#             "externalcode": []
#           },
#           {
#             "listelementId": 500014,
#             "name": "Smartwatch",
#             "description": null,
#             "availableFrom": null,
#             "availableTo": null,
#             "rank": 300,
#             "valid": true,
#             "externalcode": []
#           }
#         ],
#         "validationrule": [],
#         "aspect": [
#           "SelfActive Erfassung",
#           "Vertragsvorlage",
#           "TouchActive Erfassung",
#           "CollActive Erfassung"
#         ],
#         "evaluation": [],
#         "externalcode": []
#       }
#     ]
#   },
#   {
#     "name": "Vertragsdetails",
#     "displayName": "Vertragsdetails",
#     "rank": 100,
#     "expandable": false,
#     "collapse": null,
#     "header": "",
#     "footer": "",
#     "displayAttributeCategoryDtoMap": {
#       "Beitragsberechnung": {
#         "collapse": null,
#         "header": "",
#         "footer": ""
#       },
#       "SelfActive Erfassung": {
#         "collapse": null,
#         "header": "",
#         "footer": ""
#       },
#       "TouchActive Extra": {
#         "collapse": null,
#         "header": "",
#         "footer": ""
#       },
#       "Vertriebskennzeichen": {
#         "collapse": null,
#         "header": "",
#         "footer": ""
#       },
#       "Provisionierung": {
#         "collapse": null,
#         "header": "",
#         "footer": ""
#       },
#       "CollActive Erfassung": {
#         "collapse": null,
#         "header": "",
#         "footer": ""
#       },
#       "Eingabedaten": {
#         "collapse": null,
#         "header": "",
#         "footer": ""
#       },
#       "Vertragsvorlage": {
#         "collapse": null,
#         "header": "",
#         "footer": ""
#       },
#       "Dokumentgenerierung": {
#         "collapse": null,
#         "header": "",
#         "footer": ""
#       },
#       "TouchActive Erfassung": {
#         "collapse": null,
#         "header": "",
#         "footer": ""
#       }
#     },
#     "attribute": [
#       {
#         "attributeId": 658,
#         "productVariantAttributeId": 16873,
#         "name": "Vertragsbeginn",
#         "displayName": "Vertragsbeginn",
#         "displayDescription": "",
#         "catName": "Vertragsdetails",
#         "catDisplayName": "Vertragsdetails",
#         "catRank": 100,
#         "attributeCategoryId": 2,
#         "placeholder": null,
#         "description": "",
#         "type": "Datum",
#         "typeId": -102012,
#         "value": null,
#         "inputField": true,
#         "hide": true,
#         "advanced": false,
#         "dynamicLoaderId": null,
#         "productVariantId": 3415,
#         "productName": "HandySchutzbrief Basis Check24",
#         "personAttributeTypeId": null,
#         "documentAttributeTypeId": null,
#         "businessObjectAttributeTypeId": null,
#         "required": false,
#         "rank": 50,
#         "listId": null,
#         "properties": {},
#         "autocomplete": null,
#         "autofocus": null,
#         "readonly": null,
#         "size": null,
#         "min": null,
#         "max": null,
#         "minDate": null,
#         "maxDate": null,
#         "minLength": null,
#         "maxLength": null,
#         "placeholderDpva": null,
#         "stepwise": null,
#         "aspectDisplayNames": {},
#         "listelement": null,
#         "validationrule": [],
#         "aspect": [
#           "SelfActive Erfassung"
#         ],
#         "evaluation": [],
#         "externalcode": []
#       },
#       {
#         "attributeId": 340,
#         "productVariantAttributeId": 12856,
#         "name": "weltweiter Rundum-Schutz",
#         "displayName": "weltweiter Rundum-Schutz",
#         "displayDescription": "",
#         "catName": "Vertragsdetails",
#         "catDisplayName": "Vertragsdetails",
#         "catRank": 100,
#         "attributeCategoryId": 2,
#         "placeholder": null,
#         "description": "",
#         "type": "Auswahl",
#         "typeId": -102010,
#         "value": "true",
#         "inputField": false,
#         "hide": false,
#         "advanced": true,
#         "dynamicLoaderId": null,
#         "productVariantId": 3415,
#         "productName": "HandySchutzbrief Basis Check24",
#         "personAttributeTypeId": null,
#         "documentAttributeTypeId": null,
#         "businessObjectAttributeTypeId": null,
#         "required": false,
#         "rank": 100,
#         "listId": null,
#         "properties": {},
#         "autocomplete": null,
#         "autofocus": null,
#         "readonly": null,
#         "size": null,
#         "min": null,
#         "max": null,
#         "minDate": null,
#         "maxDate": null,
#         "minLength": null,
#         "maxLength": null,
#         "placeholderDpva": "",
#         "stepwise": null,
#         "aspectDisplayNames": {},
#         "listelement": null,
#         "validationrule": null,
#         "aspect": [
#           "SelfActive Erfassung",
#           "TouchActive Erfassung",
#           "Vertriebskennzeichen",
#           "CollActive Erfassung"
#         ],
#         "evaluation": [],
#         "externalcode": []
#       },
#       {
#         "attributeId": 343,
#         "productVariantAttributeId": 12859,
#         "name": "neu oder gebraucht",
#         "displayName": "1 neues oder gebrauchtes Handy (jedes Ger\u00e4tealter)",
#         "displayDescription": "",
#         "catName": "Vertragsdetails",
#         "catDisplayName": "Vertragsdetails",
#         "catRank": 100,
#         "attributeCategoryId": 2,
#         "placeholder": null,
#         "description": "",
#         "type": "Auswahl",
#         "typeId": -102010,
#         "value": "true",
#         "inputField": false,
#         "hide": false,
#         "advanced": true,
#         "dynamicLoaderId": null,
#         "productVariantId": 3415,
#         "productName": "HandySchutzbrief Basis Check24",
#         "personAttributeTypeId": null,
#         "documentAttributeTypeId": null,
#         "businessObjectAttributeTypeId": null,
#         "required": false,
#         "rank": 210,
#         "listId": null,
#         "properties": {},
#         "autocomplete": null,
#         "autofocus": null,
#         "readonly": null,
#         "size": null,
#         "min": null,
#         "max": null,
#         "minDate": null,
#         "maxDate": null,
#         "minLength": null,
#         "maxLength": null,
#         "placeholderDpva": "",
#         "stepwise": null,
#         "aspectDisplayNames": {},
#         "listelement": null,
#         "validationrule": null,
#         "aspect": [
#           "SelfActive Erfassung",
#           "TouchActive Erfassung",
#           "Vertriebskennzeichen",
#           "CollActive Erfassung"
#         ],
#         "evaluation": [],
#         "externalcode": []
#       },
#       {
#         "attributeId": 256,
#         "productVariantAttributeId": 12862,
#         "name": "Sch\u00e4den am Frontdisplay",
#         "displayName": "Displaysch\u00e4den",
#         "displayDescription": "",
#         "catName": "Vertragsdetails",
#         "catDisplayName": "Vertragsdetails",
#         "catRank": 100,
#         "attributeCategoryId": 2,
#         "placeholder": null,
#         "description": "",
#         "type": "Auswahl",
#         "typeId": -102010,
#         "value": "true",
#         "inputField": false,
#         "hide": false,
#         "advanced": true,
#         "dynamicLoaderId": null,
#         "productVariantId": 3415,
#         "productName": "HandySchutzbrief Basis Check24",
#         "personAttributeTypeId": null,
#         "documentAttributeTypeId": null,
#         "businessObjectAttributeTypeId": null,
#         "required": false,
#         "rank": 400,
#         "listId": null,
#         "properties": {},
#         "autocomplete": null,
#         "autofocus": null,
#         "readonly": null,
#         "size": null,
#         "min": null,
#         "max": null,
#         "minDate": null,
#         "maxDate": null,
#         "minLength": null,
#         "maxLength": null,
#         "placeholderDpva": "",
#         "stepwise": null,
#         "aspectDisplayNames": {},
#         "listelement": null,
#         "validationrule": null,
#         "aspect": [
#           "SelfActive Erfassung",
#           "TouchActive Erfassung",
#           "Vertriebskennzeichen",
#           "CollActive Erfassung"
#         ],
#         "evaluation": [],
#         "externalcode": []
#       },
#       {
#         "attributeId": 346,
#         "productVariantAttributeId": 12865,
#         "name": "Verschlei\u00df Akku",
#         "displayName": "Verschlei\u00df Akku",
#         "displayDescription": "",
#         "catName": "Vertragsdetails",
#         "catDisplayName": "Vertragsdetails",
#         "catRank": 100,
#         "attributeCategoryId": 2,
#         "placeholder": null,
#         "description": "",
#         "type": "Auswahl",
#         "typeId": -102010,
#         "value": "false",
#         "inputField": false,
#         "hide": false,
#         "advanced": true,
#         "dynamicLoaderId": null,
#         "productVariantId": 3415,
#         "productName": "HandySchutzbrief Basis Check24",
#         "personAttributeTypeId": null,
#         "documentAttributeTypeId": null,
#         "businessObjectAttributeTypeId": null,
#         "required": false,
#         "rank": 410,
#         "listId": null,
#         "properties": {},
#         "autocomplete": null,
#         "autofocus": null,
#         "readonly": null,
#         "size": null,
#         "min": null,
#         "max": null,
#         "minDate": null,
#         "maxDate": null,
#         "minLength": null,
#         "maxLength": null,
#         "placeholderDpva": "",
#         "stepwise": null,
#         "aspectDisplayNames": {},
#         "listelement": null,
#         "validationrule": null,
#         "aspect": [
#           "SelfActive Erfassung",
#           "TouchActive Erfassung",
#           "Vertriebskennzeichen",
#           "CollActive Erfassung"
#         ],
#         "evaluation": [],
#         "externalcode": []
#       },
#       {
#         "attributeId": 349,
#         "productVariantAttributeId": 12868,
#         "name": "Garantieverl\u00e4ngerung",
#         "displayName": "Garantieverl\u00e4ngerung nach Ablauf der Garantie",
#         "displayDescription": "",
#         "catName": "Vertragsdetails",
#         "catDisplayName": "Vertragsdetails",
#         "catRank": 100,
#         "attributeCategoryId": 2,
#         "placeholder": null,
#         "description": "",
#         "type": "Auswahl",
#         "typeId": -102010,
#         "value": "true",
#         "inputField": false,
#         "hide": false,
#         "advanced": true,
#         "dynamicLoaderId": null,
#         "productVariantId": 3415,
#         "productName": "HandySchutzbrief Basis Check24",
#         "personAttributeTypeId": null,
#         "documentAttributeTypeId": null,
#         "businessObjectAttributeTypeId": null,
#         "required": false,
#         "rank": 420,
#         "listId": null,
#         "properties": {},
#         "autocomplete": null,
#         "autofocus": null,
#         "readonly": null,
#         "size": null,
#         "min": null,
#         "max": null,
#         "minDate": null,
#         "maxDate": null,
#         "minLength": null,
#         "maxLength": null,
#         "placeholderDpva": "",
#         "stepwise": null,
#         "aspectDisplayNames": {},
#         "listelement": null,
#         "validationrule": null,
#         "aspect": [
#           "SelfActive Erfassung",
#           "TouchActive Erfassung",
#           "Vertriebskennzeichen",
#           "CollActive Erfassung"
#         ],
#         "evaluation": [],
#         "externalcode": []
#       },
#       {
#         "attributeId": 352,
#         "productVariantAttributeId": 12871,
#         "name": "Fl\u00fcssigkeitssch\u00e4den",
#         "displayName": "Fl\u00fcssigkeitssch\u00e4den inkl. Witterung",
#         "displayDescription": "",
#         "catName": "Vertragsdetails",
#         "catDisplayName": "Vertragsdetails",
#         "catRank": 100,
#         "attributeCategoryId": 2,
#         "placeholder": null,
#         "description": "",
#         "type": "Auswahl",
#         "typeId": -102010,
#         "value": "true",
#         "inputField": false,
#         "hide": false,
#         "advanced": true,
#         "dynamicLoaderId": null,
#         "productVariantId": 3415,
#         "productName": "HandySchutzbrief Basis Check24",
#         "personAttributeTypeId": null,
#         "documentAttributeTypeId": null,
#         "businessObjectAttributeTypeId": null,
#         "required": false,
#         "rank": 430,
#         "listId": null,
#         "properties": {},
#         "autocomplete": null,
#         "autofocus": null,
#         "readonly": null,
#         "size": null,
#         "min": null,
#         "max": null,
#         "minDate": null,
#         "maxDate": null,
#         "minLength": null,
#         "maxLength": null,
#         "placeholderDpva": "",
#         "stepwise": null,
#         "aspectDisplayNames": {},
#         "listelement": null,
#         "validationrule": null,
#         "aspect": [
#           "SelfActive Erfassung",
#           "TouchActive Erfassung",
#           "Vertriebskennzeichen",
#           "CollActive Erfassung"
#         ],
#         "evaluation": [],
#         "externalcode": []
#       },
#       {
#         "attributeId": 355,
#         "productVariantAttributeId": 12874,
#         "name": "Diebstahl",
#         "displayName": "Diebstahl",
#         "displayDescription": "",
#         "catName": "Vertragsdetails",
#         "catDisplayName": "Vertragsdetails",
#         "catRank": 100,
#         "attributeCategoryId": 2,
#         "placeholder": null,
#         "description": "",
#         "type": "Auswahl",
#         "typeId": -102010,
#         "value": "false",
#         "inputField": false,
#         "hide": false,
#         "advanced": true,
#         "dynamicLoaderId": null,
#         "productVariantId": 3415,
#         "productName": "HandySchutzbrief Basis Check24",
#         "personAttributeTypeId": null,
#         "documentAttributeTypeId": null,
#         "businessObjectAttributeTypeId": null,
#         "required": false,
#         "rank": 440,
#         "listId": null,
#         "properties": {},
#         "autocomplete": null,
#         "autofocus": null,
#         "readonly": null,
#         "size": null,
#         "min": null,
#         "max": null,
#         "minDate": null,
#         "maxDate": null,
#         "minLength": null,
#         "maxLength": null,
#         "placeholderDpva": "",
#         "stepwise": null,
#         "aspectDisplayNames": {},
#         "listelement": null,
#         "validationrule": null,
#         "aspect": [
#           "SelfActive Erfassung",
#           "TouchActive Erfassung",
#           "Vertriebskennzeichen",
#           "CollActive Erfassung"
#         ],
#         "evaluation": [],
#         "externalcode": []
#       },
#       {
#         "attributeId": 23,
#         "productVariantAttributeId": 12847,
#         "name": "Selbstbeteiligung 10% vom Kaufpreis",
#         "displayName": "Selbstbeteiligung 10% vom Kaufpreis",
#         "displayDescription": "",
#         "catName": "Vertragsdetails",
#         "catDisplayName": "Vertragsdetails",
#         "catRank": 100,
#         "attributeCategoryId": 2,
#         "placeholder": null,
#         "description": "",
#         "type": "Auswahl",
#         "typeId": -102010,
#         "value": "true",
#         "inputField": false,
#         "hide": false,
#         "advanced": false,
#         "dynamicLoaderId": null,
#         "productVariantId": 3415,
#         "productName": "HandySchutzbrief Basis Check24",
#         "personAttributeTypeId": null,
#         "documentAttributeTypeId": null,
#         "businessObjectAttributeTypeId": null,
#         "required": false,
#         "rank": 700,
#         "listId": null,
#         "properties": {},
#         "autocomplete": null,
#         "autofocus": null,
#         "readonly": null,
#         "size": null,
#         "min": null,
#         "max": null,
#         "minDate": null,
#         "maxDate": null,
#         "minLength": null,
#         "maxLength": null,
#         "placeholderDpva": "",
#         "stepwise": null,
#         "aspectDisplayNames": {},
#         "listelement": null,
#         "validationrule": null,
#         "aspect": [
#           "SelfActive Erfassung",
#           "TouchActive Erfassung",
#           "Vertriebskennzeichen",
#           "Beitragsberechnung",
#           "CollActive Erfassung"
#         ],
#         "evaluation": [],
#         "externalcode": []
#       },
#       {
#         "attributeId": 20,
#         "productVariantAttributeId": 12913,
#         "name": "T\u00e4gliche K\u00fcndigungsoption",
#         "displayName": "T\u00e4gliche K\u00fcndigungsoption",
#         "displayDescription": "",
#         "catName": "Vertragsdetails",
#         "catDisplayName": "Vertragsdetails",
#         "catRank": 100,
#         "attributeCategoryId": 2,
#         "placeholder": null,
#         "description": "",
#         "type": "Auswahl",
#         "typeId": -102010,
#         "value": "true",
#         "inputField": false,
#         "hide": false,
#         "advanced": true,
#         "dynamicLoaderId": null,
#         "productVariantId": 3415,
#         "productName": "HandySchutzbrief Basis Check24",
#         "personAttributeTypeId": null,
#         "documentAttributeTypeId": null,
#         "businessObjectAttributeTypeId": null,
#         "required": false,
#         "rank": 800,
#         "listId": null,
#         "properties": {},
#         "autocomplete": null,
#         "autofocus": null,
#         "readonly": null,
#         "size": null,
#         "min": null,
#         "max": null,
#         "minDate": null,
#         "maxDate": null,
#         "minLength": null,
#         "maxLength": null,
#         "placeholderDpva": "",
#         "stepwise": null,
#         "aspectDisplayNames": {},
#         "listelement": null,
#         "validationrule": null,
#         "aspect": [
#           "SelfActive Erfassung",
#           "TouchActive Erfassung",
#           "Vertriebskennzeichen",
#           "CollActive Erfassung"
#         ],
#         "evaluation": [],
#         "externalcode": []
#       },
#       {
#         "attributeId": 397,
#         "productVariantAttributeId": 12916,
#         "name": "Wartefrist Wochen",
#         "displayName": "Wartefrist Wochen",
#         "displayDescription": "Wird der Versicherungsvertrag f\u00fcr das versicherte Ger\u00e4t erst nach dem Kaufdatum abgeschlossen, gilt eine Wartezeit von vier Wochen ab Abschluss des Versicherungsvertrages. F\u00fcr vor oder w\u00e4hrend der Wartezeit eingetretene\r\nVersicherungsf\u00e4lle besteht kein Versicherungsschutz.",
#         "catName": "Vertragsdetails",
#         "catDisplayName": "Vertragsdetails",
#         "catRank": 100,
#         "attributeCategoryId": 2,
#         "placeholder": null,
#         "description": "Wird der Versicherungsvertrag f\u00fcr das versicherte Ger\u00e4t erst nach dem Kaufdatum abgeschlossen, gilt eine Wartezeit von vier Wochen ab Abschluss des Versicherungsvertrages. F\u00fcr vor oder w\u00e4hrend der Wartezeit eingetretene\r\nVersicherungsf\u00e4lle besteht kein Versicherungsschutz.",
#         "type": "Zahl",
#         "typeId": -102011,
#         "value": null,
#         "inputField": false,
#         "hide": true,
#         "advanced": true,
#         "dynamicLoaderId": null,
#         "productVariantId": 3415,
#         "productName": "HandySchutzbrief Basis Check24",
#         "personAttributeTypeId": null,
#         "documentAttributeTypeId": null,
#         "businessObjectAttributeTypeId": null,
#         "required": false,
#         "rank": 10000,
#         "listId": null,
#         "properties": {},
#         "autocomplete": null,
#         "autofocus": null,
#         "readonly": null,
#         "size": null,
#         "min": null,
#         "max": null,
#         "minDate": null,
#         "maxDate": null,
#         "minLength": null,
#         "maxLength": null,
#         "placeholderDpva": null,
#         "stepwise": null,
#         "aspectDisplayNames": {},
#         "listelement": null,
#         "validationrule": null,
#         "aspect": [
#           "SelfActive Erfassung"
#         ],
#         "evaluation": [],
#         "externalcode": []
#       },
#       {
#         "attributeId": 472,
#         "productVariantAttributeId": 12904,
#         "name": "Wartefrist Wochen 2",
#         "displayName": "Wartefrist (in Wochen) nach Ger\u00e4tealter",
#         "displayDescription": "Wird der Versicherungsvertrag f\u00fcr das versicherte Ger\u00e4t erst nach dem Kaufdatum abgeschlossen, kannst du Dein Ger\u00e4t kostenpflichtig und auf Dein eigenes Risiko zur \u00dcberpr\u00fcfung an die Smartphoniker GmbH, Ger\u00e4tepr\u00fcfung Schutzgarant, Bahnhofstra\u00dfe 30, 24223 Schwentinental einsenden, um das Ger\u00e4t ohne Wartezeit zu versichern. Sobald die SCHUZTGARANT GmbH Schadenservice den mangelfreien Zustand best\u00e4tigt, verzichten wir auf die Wartezeit. Schickst Du Dein Ger\u00e4t nicht zur \u00dcberpr\u00fcfung ein gilt f\u00fcr Ger\u00e4te mit einem Ger\u00e4tealter bis 42 Tage keine Wartezeit, f\u00fcr Ger\u00e4te mit einem Ger\u00e4tealter bis 180 Tage eine Wartezeit von sechs Wochen ab Abschluss des Versicherungsvertrages. F\u00fcr Ger\u00e4te mit einem Ger\u00e4tealter bis 360 Tage gilt eine Wartezeit von zw\u00f6lf Wochen ab Abschluss des Versicherungsvertrages. Ger\u00e4te, die \u00e4lter als 360 Tage bei Abschluss des Versicherungsvertrages sind k\u00f6nnen nur mit \u00dcberpr\u00fcfung versichert werden. Die Berechnung des Ger\u00e4tealters erfolgt auf Grundlage des Kaufdatums des Ger\u00e4tes, welches Du durch einen Kaufbeleg nachweisen musst. F\u00fcr vor oder w\u00e4hrend der Wartezeit eingetretene Versicherungsf\u00e4lle besteht kein Versicherungsschutz.",
#         "catName": "Vertragsdetails",
#         "catDisplayName": "Vertragsdetails",
#         "catRank": 100,
#         "attributeCategoryId": 2,
#         "placeholder": null,
#         "description": "Wird der Versicherungsvertrag f\u00fcr das versicherte Ger\u00e4t erst nach dem Kaufdatum abgeschlossen, kannst du Dein Ger\u00e4t kostenpflichtig und auf Dein eigenes Risiko zur \u00dcberpr\u00fcfung an die Smartphoniker GmbH, Ger\u00e4tepr\u00fcfung Schutzgarant, Bahnhofstra\u00dfe 30, 24223 Schwentinental einsenden, um das Ger\u00e4t ohne Wartezeit zu versichern. Sobald die SCHUZTGARANT GmbH Schadenservice den mangelfreien Zustand best\u00e4tigt, verzichten wir auf die Wartezeit. Schickst Du Dein Ger\u00e4t nicht zur \u00dcberpr\u00fcfung ein gilt f\u00fcr Ger\u00e4te mit einem Ger\u00e4tealter bis 42 Tage keine Wartezeit, f\u00fcr Ger\u00e4te mit einem Ger\u00e4tealter bis 180 Tage eine Wartezeit von sechs Wochen ab Abschluss des Versicherungsvertrages. F\u00fcr Ger\u00e4te mit einem Ger\u00e4tealter bis 360 Tage gilt eine Wartezeit von zw\u00f6lf Wochen ab Abschluss des Versicherungsvertrages. Ger\u00e4te, die \u00e4lter als 360 Tage bei Abschluss des Versicherungsvertrages sind k\u00f6nnen nur mit \u00dcberpr\u00fcfung versichert werden. Die Berechnung des Ger\u00e4tealters erfolgt auf Grundlage des Kaufdatums des Ger\u00e4tes, welches Du durch einen Kaufbeleg nachweisen musst. F\u00fcr vor oder w\u00e4hrend der Wartezeit eingetretene Versicherungsf\u00e4lle besteht kein Versicherungsschutz.",
#         "type": "Name-Wert",
#         "typeId": -102159,
#         "value": "Tage[42]=0\r\nTage[180]=6\r\nTage[3000]=12",
#         "inputField": false,
#         "hide": true,
#         "advanced": false,
#         "dynamicLoaderId": null,
#         "productVariantId": 3415,
#         "productName": "HandySchutzbrief Basis Check24",
#         "personAttributeTypeId": null,
#         "documentAttributeTypeId": null,
#         "businessObjectAttributeTypeId": null,
#         "required": false,
#         "rank": 10000,
#         "listId": null,
#         "properties": {},
#         "autocomplete": null,
#         "autofocus": null,
#         "readonly": null,
#         "size": null,
#         "min": null,
#         "max": null,
#         "minDate": null,
#         "maxDate": null,
#         "minLength": null,
#         "maxLength": null,
#         "placeholderDpva": "",
#         "stepwise": null,
#         "aspectDisplayNames": {},
#         "listelement": null,
#         "validationrule": null,
#         "aspect": [
#           "SelfActive Erfassung",
#           "TouchActive Extra"
#         ],
#         "evaluation": [],
#         "externalcode": []
#       },
#       {
#         "attributeId": 544,
#         "productVariantAttributeId": 12919,
#         "name": "Schutzbeginn",
#         "displayName": "Schutzbeginn",
#         "displayDescription": "",
#         "catName": "Vertragsdetails",
#         "catDisplayName": "Vertragsdetails",
#         "catRank": 100,
#         "attributeCategoryId": 2,
#         "placeholder": null,
#         "description": "",
#         "type": "Datum",
#         "typeId": -102012,
#         "value": null,
#         "inputField": false,
#         "hide": true,
#         "advanced": true,
#         "dynamicLoaderId": null,
#         "productVariantId": 3415,
#         "productName": "HandySchutzbrief Basis Check24",
#         "personAttributeTypeId": null,
#         "documentAttributeTypeId": null,
#         "businessObjectAttributeTypeId": null,
#         "required": false,
#         "rank": 10000,
#         "listId": null,
#         "properties": {},
#         "autocomplete": null,
#         "autofocus": null,
#         "readonly": null,
#         "size": null,
#         "min": null,
#         "max": null,
#         "minDate": null,
#         "maxDate": null,
#         "minLength": null,
#         "maxLength": null,
#         "placeholderDpva": null,
#         "stepwise": null,
#         "aspectDisplayNames": {},
#         "listelement": null,
#         "validationrule": null,
#         "aspect": [
#           "SelfActive Erfassung"
#         ],
#         "evaluation": [],
#         "externalcode": []
#       },
#       {
#         "attributeId": 367,
#         "productVariantAttributeId": 12883,
#         "name": "Selbstbeteiligung",
#         "displayName": "Selbstbeteiligung",
#         "displayDescription": "",
#         "catName": "Vertragsdetails",
#         "catDisplayName": "Vertragsdetails",
#         "catRank": 100,
#         "attributeCategoryId": 2,
#         "placeholder": null,
#         "description": "",
#         "type": "W\u00e4hrung",
#         "typeId": -102160,
#         "value": "0.00",
#         "inputField": true,
#         "hide": true,
#         "advanced": true,
#         "dynamicLoaderId": null,
#         "productVariantId": 3415,
#         "productName": "HandySchutzbrief Basis Check24",
#         "personAttributeTypeId": null,
#         "documentAttributeTypeId": null,
#         "businessObjectAttributeTypeId": null,
#         "required": false,
#         "rank": 10700,
#         "listId": null,
#         "properties": {},
#         "autocomplete": null,
#         "autofocus": null,
#         "readonly": null,
#         "size": null,
#         "min": null,
#         "max": null,
#         "minDate": null,
#         "maxDate": null,
#         "minLength": null,
#         "maxLength": null,
#         "placeholderDpva": "",
#         "stepwise": null,
#         "aspectDisplayNames": {},
#         "listelement": null,
#         "validationrule": [],
#         "aspect": [
#           "TouchActive Extra",
#           "Beitragsberechnung",
#           "SelfActive Erfassung"
#         ],
#         "evaluation": [],
#         "externalcode": []
#       }
#     ]
#   },
#   {
#     "name": "Zahlungsinformationen",
#     "displayName": "Zahlungsinformationen",
#     "rank": 200,
#     "expandable": false,
#     "collapse": null,
#     "header": "",
#     "footer": "",
#     "displayAttributeCategoryDtoMap": {
#       "Beitragsberechnung": {
#         "collapse": null,
#         "header": "",
#         "footer": ""
#       },
#       "SelfActive Erfassung": {
#         "collapse": null,
#         "header": "",
#         "footer": ""
#       },
#       "Konfiguration": {
#         "collapse": null,
#         "header": "",
#         "footer": ""
#       },
#       "TouchActive Erfassung": {
#         "collapse": null,
#         "header": "",
#         "footer": ""
#       }
#     },
#     "attribute": [
#       {
#         "attributeId": 376,
#         "productVariantAttributeId": 12889,
#         "name": "Zahlungsart",
#         "displayName": "Zahlungsart",
#         "displayDescription": "",
#         "catName": "Zahlungsinformationen",
#         "catDisplayName": "Zahlungsinformationen",
#         "catRank": 200,
#         "attributeCategoryId": 11,
#         "placeholder": null,
#         "description": "",
#         "type": "Liste",
#         "typeId": -102014,
#         "value": "Lastschrift",
#         "inputField": true,
#         "hide": true,
#         "advanced": false,
#         "dynamicLoaderId": null,
#         "productVariantId": 3415,
#         "productName": "HandySchutzbrief Basis Check24",
#         "personAttributeTypeId": null,
#         "documentAttributeTypeId": null,
#         "businessObjectAttributeTypeId": null,
#         "required": false,
#         "rank": 100,
#         "listId": -59,
#         "properties": {},
#         "autocomplete": null,
#         "autofocus": null,
#         "readonly": null,
#         "size": null,
#         "min": null,
#         "max": null,
#         "minDate": null,
#         "maxDate": null,
#         "minLength": null,
#         "maxLength": null,
#         "placeholderDpva": "",
#         "stepwise": null,
#         "aspectDisplayNames": {},
#         "listelement": [
#           {
#             "listelementId": -5902,
#             "name": "Lastschrift",
#             "description": null,
#             "availableFrom": null,
#             "availableTo": null,
#             "rank": 0,
#             "valid": true,
#             "externalcode": []
#           }
#         ],
#         "validationrule": [
#           {
#             "regularExpression": "(Lastschrift)",
#             "min": null,
#             "max": null,
#             "expectedValidationResult": true,
#             "validationFailureMessage": "Nur Lastschrift ist zul\u00e4ssig",
#             "validationFailureI18N": null,
#             "minDate": null,
#             "maxDate": null,
#             "stepwise": null,
#             "minLength": null,
#             "maxLength": null
#           }
#         ],
#         "aspect": [
#           "SelfActive Erfassung",
#           "TouchActive Erfassung",
#           "CollActive Erfassung"
#         ],
#         "evaluation": [],
#         "externalcode": []
#       },
#       {
#         "attributeId": 379,
#         "productVariantAttributeId": 12892,
#         "name": "Zahlungsweise",
#         "displayName": "Zahlungsweise",
#         "displayDescription": "",
#         "catName": "Zahlungsinformationen",
#         "catDisplayName": "Zahlungsinformationen",
#         "catRank": 200,
#         "attributeCategoryId": 11,
#         "placeholder": null,
#         "description": "",
#         "type": "Liste",
#         "typeId": -102014,
#         "value": "monatlich",
#         "inputField": true,
#         "hide": true,
#         "advanced": false,
#         "dynamicLoaderId": null,
#         "productVariantId": 3415,
#         "productName": "HandySchutzbrief Basis Check24",
#         "personAttributeTypeId": null,
#         "documentAttributeTypeId": null,
#         "businessObjectAttributeTypeId": null,
#         "required": false,
#         "rank": 200,
#         "listId": -51,
#         "properties": {},
#         "autocomplete": null,
#         "autofocus": null,
#         "readonly": null,
#         "size": null,
#         "min": null,
#         "max": null,
#         "minDate": null,
#         "maxDate": null,
#         "minLength": null,
#         "maxLength": null,
#         "placeholderDpva": "",
#         "stepwise": null,
#         "aspectDisplayNames": {},
#         "listelement": [
#           {
#             "listelementId": -5101,
#             "name": "monatlich",
#             "description": "",
#             "availableFrom": null,
#             "availableTo": null,
#             "rank": 10,
#             "valid": true,
#             "externalcode": []
#           }
#         ],
#         "validationrule": [
#           {
#             "regularExpression": "^(monatlich)$",
#             "min": null,
#             "max": null,
#             "expectedValidationResult": true,
#             "validationFailureMessage": "Nur monatliche Zahlweise ist zul\u00e4ssig",
#             "validationFailureI18N": null,
#             "minDate": null,
#             "maxDate": null,
#             "stepwise": null,
#             "minLength": null,
#             "maxLength": null
#           }
#         ],
#         "aspect": [
#           "SelfActive Erfassung",
#           "TouchActive Erfassung",
#           "CollActive Erfassung"
#         ],
#         "evaluation": [],
#         "externalcode": []
#       }
#     ]
#   }
# ]

# %%
# attributes = data[1]['attributecategorie'][0]['attribute']
attributes = [
    attr
    for cat in data[1]['attributecategorie']
    for attr in cat['attribute']
]

attribute_model = generate_attribute_model('attributes', attributes)
print(json.dumps(attribute_model.model_json_schema(),indent=2))
# Out:
# {
#   "properties": {
#     "attribute_331": {
#       "default": "Handy/Smartphone",
#       "description": " (allowed: Handy/Smartphone, Tablet, Smartwatch)",
#       "enum": [
#         "Handy/Smartphone",
#         "Tablet",
#         "Smartwatch"
#       ],
#       "title": "Ger\u00e4tetyp",
#       "type": "string"
#     }
#   },
#   "title": "attributes",
#   "type": "object"
# }

# %%
print("\nValid case:")
attribute = attribute_model(
    attribute_331="Tablet",
    attribute_555=123456,
    attribute_777="2024-07-25"
)
print(attribute.model_dump_json(indent=2))
# Out:
# Valid case:
# {
#   "attribute_331": "Tablet"
# }

# %%
modules = []
for sub_prod in data[1]["subproduct"]:
    ppv_id = sub_prod["partProductVariantId"]
    if not ppv_id in [19, 3112, 3091]:
        modules.extend(
            # sub_prod["productTreeRenderData"]
            [
                attr
                for cat in sub_prod["productTreeRenderData"]['attributecategorie']
                for attr in cat['attribute']
            ]
        )
# print(json.dumps(modules,indent=2))
module_model = generate_attribute_model('modules', modules)
print(json.dumps(module_model.model_json_schema(),indent=2))
# Out:
# {
#   "properties": {
#     "attribute_604": {
#       "anyOf": [
#         {
#           "type": "boolean"
#         },
#         {
#           "type": "null"
#         }
#       ],
#       "default": false,
#       "description": "",
#       "title": "Ich kenne meine IMEI-/Seriennummer noch nicht"
#     },
#     "attribute_67": {
#       "anyOf": [
#         {
#           "type": "string"
#         },
#         {
#           "type": "null"
#         }
#       ],
#       "default": "",
#       "description": "",
#       "title": "IMEI-/Seriennummer"
#     },
#     "attribute_3730": {
#       "default": "501 - 750 \u20ac",
#       "description": " (allowed: 0 - 250 \u20ac, 251 - 500 \u20ac, 501 - 750 \u20ac, 751 - 1.000 \u20ac, 1.001 - 1.250 \u20ac, 1.251 - 1.500 \u20ac, 1.501 - 1.750 \u20ac, 1.751 - 2.000 \u20ac, 2.001 - 2.500 \u20ac, 2.501 - 3.000 \u20ac)",
#       "enum": [
#         "0 - 250 \u20ac",
#         "251 - 500 \u20ac",
#         "501 - 750 \u20ac",
#         "751 - 1.000 \u20ac",
#         "1.001 - 1.250 \u20ac",
#         "1.251 - 1.500 \u20ac",
#         "1.501 - 1.750 \u20ac",
#         "1.751 - 2.000 \u20ac",
#         "2.001 - 2.500 \u20ac",
#         "2.501 - 3.000 \u20ac"
#       ],
#       "title": "Unsubventionierter Kaufpreis",
#       "type": "string"
#     },
#     "attribute_3733": {
#       "default": "bis 2 Wochen",
#       "description": " (allowed: bis 2 Wochen, 2 Wochen bis 6 Wochen, 6 Wochen bis halbes Jahr, halbes Jahr bis 1 Jahr, 1 Jahr bis 2 Jahre, \u00e4lter als 2 Jahre)",
#       "enum": [
#         "bis 2 Wochen",
#         "2 Wochen bis 6 Wochen",
#         "6 Wochen bis halbes Jahr",
#         "halbes Jahr bis 1 Jahr",
#         "1 Jahr bis 2 Jahre",
#         "\u00e4lter als 2 Jahre"
#       ],
#       "title": "Ger\u00e4tealter",
#       "type": "string"
#     },
#     "attribute_70": {
#       "description": " (allowed: Samsung, Apple, Huawei, Xiaomi, Acer, AEG, Alcatel, Allview, Amica, Asus, ATAG, Bauknecht, BEKO, Blackberry, Blomberg, Bomann, Bosch (BSH), Candy, Canon, CAT, Caterpillar, Clatronic, Constructa, Cubot, DELL, Doro, Electrolux, Elektra Bregenz, Epson, Exquisit, Fagor, Fairphone, Fujifilm, Fujitsu, Gaggenau, Gigaset, Google, GoPro, Gorenje, Grundig, Haier, Hewlett Packard/HP, Honor, Hoover, HTC, Ignis, Ikea, Indesit, ISY, Juno, Koenic, K\u00f6rting, K\u00fcppersbusch, Leica, Lenovo, LG, Liebherr, Microsoft, Miele, Motorola, Neff, Nikon, Nokia, ok, Olympus, OnePlus, OPPO, Oranier, Panasonic, PEAQ, Privileg, Progress, Schaub Lorenz, Sharp, Sibir, Siemens, Smeg, Sony, Teka, Termikel, UleFone, Vivo, Whirlpool, Wiko, Zanker, Zanussi, ZTE, Sonstige)",
#       "enum": [
#         "Samsung",
#         "Apple",
#         "Huawei",
#         "Xiaomi",
#         "Acer",
#         "AEG",
#         "Alcatel",
#         "Allview",
#         "Amica",
#         "Asus",
#         "ATAG",
#         "Bauknecht",
#         "BEKO",
#         "Blackberry",
#         "Blomberg",
#         "Bomann",
#         "Bosch (BSH)",
#         "Candy",
#         "Canon",
#         "CAT",
#         "Caterpillar",
#         "Clatronic",
#         "Constructa",
#         "Cubot",
#         "DELL",
#         "Doro",
#         "Electrolux",
#         "Elektra Bregenz",
#         "Epson",
#         "Exquisit",
#         "Fagor",
#         "Fairphone",
#         "Fujifilm",
#         "Fujitsu",
#         "Gaggenau",
#         "Gigaset",
#         "Google",
#         "GoPro",
#         "Gorenje",
#         "Grundig",
#         "Haier",
#         "Hewlett Packard/HP",
#         "Honor",
#         "Hoover",
#         "HTC",
#         "Ignis",
#         "Ikea",
#         "Indesit",
#         "ISY",
#         "Juno",
#         "Koenic",
#         "K\u00f6rting",
#         "K\u00fcppersbusch",
#         "Leica",
#         "Lenovo",
#         "LG",
#         "Liebherr",
#         "Microsoft",
#         "Miele",
#         "Motorola",
#         "Neff",
#         "Nikon",
#         "Nokia",
#         "ok",
#         "Olympus",
#         "OnePlus",
#         "OPPO",
#         "Oranier",
#         "Panasonic",
#         "PEAQ",
#         "Privileg",
#         "Progress",
#         "Schaub Lorenz",
#         "Sharp",
#         "Sibir",
#         "Siemens",
#         "Smeg",
#         "Sony",
#         "Teka",
#         "Termikel",
#         "UleFone",
#         "Vivo",
#         "Whirlpool",
#         "Wiko",
#         "Zanker",
#         "Zanussi",
#         "ZTE",
#         "Sonstige"
#       ],
#       "title": "Hersteller",
#       "type": "string"
#     },
#     "attribute_217": {
#       "anyOf": [
#         {
#           "type": "string"
#         },
#         {
#           "type": "null"
#         }
#       ],
#       "default": "",
#       "description": "",
#       "title": "Herstellername"
#     },
#     "attribute_130": {
#       "default": "",
#       "description": "",
#       "title": "Modell",
#       "type": "string"
#     },
#     "attribute_16": {
#       "default": 24,
#       "description": " (must be integer)",
#       "title": "Herstellergarantie (Monate)",
#       "type": "integer"
#     }
#   },
#   "required": [
#     "attribute_70"
#   ],
#   "title": "modules",
#   "type": "object"
# }

# %%
print("\nValid case:")
module = module_model(
    attribute_331="Tablet",
    attribute_555=123456,
    attribute_777="2024-07-25",
    attribute_70="Apple"
)
print(module.model_dump_json(indent=2))
# Out:
# Valid case:
# {
#   "attribute_604": false,
#   "attribute_67": "",
#   "attribute_3730": "501 - 750 €",
#   "attribute_3733": "bis 2 Wochen",
#   "attribute_70": "Apple",
#   "attribute_217": "",
#   "attribute_130": "",
#   "attribute_16": 24
# }

# %%
print(module_model.model_json_schema()["required"])
# Out:
# ['attribute_70']

# %%
attributes = data[1]['attributecategorie'][0]['attribute']
print(json.dumps(attributes, indent=2))
# data[1]['attributecategorie'][0]['attribute']
# Out:
# [
#   {
#     "attributeId": 331,
#     "productVariantAttributeId": 12853,
#     "name": "Ger\u00e4tetyp (privat)",
#     "displayName": "Ger\u00e4tetyp",
#     "displayDescription": "",
#     "catName": "Allgemeine Kategorie",
#     "catDisplayName": "Allgemeine Kategorie",
#     "catRank": 30,
#     "attributeCategoryId": -1,
#     "placeholder": null,
#     "description": "",
#     "type": "Liste",
#     "typeId": -102014,
#     "value": "Handy/Smartphone",
#     "inputField": true,
#     "hide": false,
#     "advanced": false,
#     "dynamicLoaderId": null,
#     "productVariantId": 3415,
#     "productName": "HandySchutzbrief Basis Check24",
#     "personAttributeTypeId": null,
#     "documentAttributeTypeId": null,
#     "businessObjectAttributeTypeId": null,
#     "required": true,
#     "rank": 100,
#     "listId": 25,
#     "properties": {},
#     "autocomplete": null,
#     "autofocus": null,
#     "readonly": null,
#     "size": null,
#     "min": null,
#     "max": null,
#     "minDate": null,
#     "maxDate": null,
#     "minLength": null,
#     "maxLength": null,
#     "placeholderDpva": "",
#     "stepwise": null,
#     "aspectDisplayNames": {},
#     "listelement": [
#       {
#         "listelementId": 500008,
#         "name": "Handy/Smartphone",
#         "description": null,
#         "availableFrom": null,
#         "availableTo": null,
#         "rank": 100,
#         "valid": true,
#         "externalcode": []
#       },
#       {
#         "listelementId": 500011,
#         "name": "Tablet",
#         "description": null,
#         "availableFrom": null,
#         "availableTo": null,
#         "rank": 200,
#         "valid": true,
#         "externalcode": []
#       },
#       {
#         "listelementId": 500014,
#         "name": "Smartwatch",
#         "description": null,
#         "availableFrom": null,
#         "availableTo": null,
#         "rank": 300,
#         "valid": true,
#         "externalcode": []
#       }
#     ],
#     "validationrule": [],
#     "aspect": [
#       "SelfActive Erfassung",
#       "Vertragsvorlage",
#       "TouchActive Erfassung",
#       "CollActive Erfassung"
#     ],
#     "evaluation": [],
#     "externalcode": []
#   }
# ]

# %%
attribute_model = generate_attribute_model(attributes)

# %%
# print(attribute_model)
print(json.dumps(attribute_model.model_json_schema(), indent=2))
# Out:
# {
#   "properties": {
#     "331": {
#       "default": "Handy/Smartphone",
#       "description": "Ger\u00e4tetyp, enum values: Handy/Smartphone, Tablet, Smartwatch",
#       "title": "331",
#       "type": "string"
#     }
#   },
#   "title": "DynamicAttributes",
#   "type": "object"
# }

# %%
inst = attribute_model(attributeId=331, value='Tablet')
print(inst)
# Out:
# 331='Handy/Smartphone'

# %% [markdown]
# # load test data for form submit

# %%
with open("test_data.json", "r", encoding="utf-8") as file:  
    test_data = json.load(file)

print(json.dumps(test_data, indent=2, ensure_ascii=False))
# Out:
# {
#   "productDto": {
#     "productVariantId": 3571,
#     "removed": false,
#     "attributes": [
#       {
#         "id": 15991,
#         "value": "500011"
#       },
#       {
#         "id": 15994,
#         "value": "true"
#       },
#       {
#         "id": 15997,
#         "value": "true"
#       },
#       {
#         "id": 16000,
#         "value": "true"
#       },
#       {
#         "id": 16003,
#         "value": "false"
#       },
#       {
#         "id": 16006,
#         "value": "true"
#       },
#       {
#         "id": 16009,
#         "value": "true"
#       },
#       {
#         "id": 16012,
#         "value": "false"
#       },
#       {
#         "id": 15988,
#         "value": "true"
#       },
#       {
#         "id": 16051,
#         "value": "true"
#       },
#       {
#         "id": 16045,
#         "value": "true"
#       },
#       {
#         "id": 16048,
#         "value": "true"
#       }
#     ],
#     "subproducts": [
#       {
#         "productVariantId": 3091,
#         "modules": [
#           {
#             "productVariantId": 3091,
#             "removed": false,
#             "attributes": [
#               {
#                 "id": 3751,
#                 "value": "-31"
#               },
#               {
#                 "id": 3769,
#                 "value": "John"
#               },
#               {
#                 "id": 3748,
#                 "value": "Doe"
#               },
#               {
#                 "id": 3775,
#                 "value": "1981-09-12T00:00:00+02:00"
#               },
#               {
#                 "id": 3772,
#                 "value": "{\"identifier\":\"51dcc646\",\"zipCity\":{\"identifier\":\"bdf25147\",\"zipcode\":\"14467\",\"city\":\"Potsdam\"},\"street\":\"Behlertstr.\",\"streetNumber\":\"55\",\"contryCode\":\"DE\"}"
#               },
#               {
#                 "id": 3754,
#                 "value": "abc@def.de"
#               },
#               {
#                 "id": 3757,
#                 "value": "0331647864"
#               },
#               {
#                 "id": 3760,
#                 "value": ""
#               }
#             ],
#             "subproducts": []
#           }
#         ]
#       },
#       {
#         "productVariantId": 3412,
#         "modules": [
#           {
#             "productVariantId": 3412,
#             "removed": false,
#             "attributes": [
#               {
#                 "id": 12832,
#                 "value": "false"
#               },
#               {
#                 "id": 12820,
#                 "value": "53254325345"
#               },
#               {
#                 "id": 12841,
#                 "value": "500161"
#               },
#               {
#                 "id": 12844,
#                 "value": "500182"
#               },
#               {
#                 "id": 12811,
#                 "value": "300043"
#               },
#               {
#                 "id": 12817,
#                 "value": ""
#               },
#               {
#                 "id": 12814,
#                 "value": "S8"
#               },
#               {
#                 "id": 12823,
#                 "value": "24"
#               }
#             ],
#             "subproducts": []
#           }
#         ]
#       }
#     ]
#   },
#   "suggestedProduct": {
#     "product": {
#       "productVariantId": 3571
#     }
#   },
#   "paymentInformationDto": {
#     "paymentMethod": {
#       "provider": "Deutsche Kreditbank Berlin",
#       "account2": "DE02120300000000202051",
#       "type": -161
#     },
#     "paymentManner": -5902,
#     "paymentInterval": -5101
#   },
#   "eventSender": {
#     "ip": "172.23.0.1"
#   },
#   "mainPersonId": 8391,
#   "mainPtnId": 400,
#   "contractAttributes": [],
#   "application": "KI"
# }

# %%
url = "https://test-protactive.schutzgarant.de/ca-rest/import"
params = {"dryRun": "true", "async": "true"}
headers = {"Accept": "application/json", "Content-Type": "application/json"}
session = requests.Session()
answer = session.post(
    url,
    auth=HTTPBasicAuth(user, pwd),
    headers=headers,
    params=params,
    json=test_data,
)

try:
    content = answer.json()
except Exception:
    content = answer.text
response = {"status_code": answer.status_code, "content": content}

# %%
response
# Out:
# {'status_code': 400,
#  'content': 'Unrecognized field &quot;productDto&quot; (class at.intervista.collactive.rest.external.model.Contract), not marked as ignorable'}
